# %% [markdown]
# # HRD-net  crawling

# %% [markdown]
# ## Make DataFrame, Transfrom excel

# %%
import time
import json
import urllib
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Set columns

# %%
# Columns
col = ['기관명', '과정명','훈련비(원)','훈련시간',
       'NCS 직무분류','수강생 평균 연령대(세)', 
       '수강생 평균 만족도', '회차', '훈련기간',
       '훈련시작일','훈련종료일','모집인원','수강확정인원', 
       '수강신청인원', '회차별 만족도', '취업률 고용보험가입 3개월',
       '취업인원','수료인원']
data = []

# %% [markdown]
# ### HRD-net URL

# %%
url = 'https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&tracseTme=1&crseTracseSe=C0061&trainstCstmrId=500020018488#undefined'

resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <!-- 헤더csrf -->
# <head>
# <meta content="_csrf" name="_csrf_parameter"/><meta content="X-CSRF-TOKEN" name="_csrf_header"/><meta content="6b2051f8-e9ef-400e-8087-e5ad59c11313" name="_csrf"/>
# <!--모바일여부 변수 -->
# <!--테블릿여부 변수 -->
# <!--PC여부 변수 -->
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="HRD" name="author"/>
# <meta content="all" name="robots"/>
# <meta content="HRD" name="keywords"/>
# <meta content="내일배움카드제, 근로자직무능력향상훈련, 기업체 지원훈련, 일학습병행, 전국 훈련기관." name="description"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="No-cache" http-equiv="Cache-Control"/>
# <title>직업훈련포털 HRD-Net</title>
# <!-- new 추가 -->
# <link href="/new_images/common/favicon.ico" rel="shortcut icon"/>
# <!-- <link href="/new_css/lib/swiper.css" rel="stylesheet"> -->
# <link href="/new_css/pro.css" rel="stylesheet">
# <link href="/new_images/common/favicon.ico" rel="shortcut icon"/>
# <link href="/new_css/lib/jquery-ui.css" rel="stylesheet">
# <link href="/new_css/lib/swiper.min.css" rel="stylesheet"/>
# <link href="/new_css/lib/daterangepicker.css" rel="stylesheet"/>
# <link href="/new_css/reset.css" rel="stylesheet"/>
# <link href="/new_css/layout.css" rel="stylesheet"/>
# <link href="/new_css/contents.css?ver=10" rel="stylesheet"/>
# <link href="/new_css/main.css?ver=4" rel="stylesheet"/>
# <link href="/new_css/front.css?ver=3" rel="stylesheet"/>
# <link href="/new_css/myservice.css?ver=4" rel="stylesheet"/>
# <script src="/new_js/lib/jquery-2.1.1.js"></script>
# <script src="/new_js/lib/jquery-ui.js"></script>
# <script src="/new_js/lib/moment.min.js"></script>
# <script src="/new_js/lib/daterangepicker.js"></script>
# <script src="/new_js/lib/swiper.min.js"></script>
# <script src="/new_js/ui.js?ver=1" type="text/javascript"></script>
# <link href="/new_css/contents2.css" rel="stylesheet"/>
# <link href="/new_css/renewalHeader.css?ver=0" rel="stylesheet" type="text/css"/>
# <!-- new 추가  END-->
# <script type="text/javascript">
# 	var gfv_contextpath = "";
# </script>
# <script src="/js/lib/jquery-1.9.0.js" type="text/javascript"></script>
# <script src="/js/lib/jquery-ui.js" type="text/javascript"></script>
# <script src="/js/lib/jquery.easing.1.3.min.js" type="text/javascript"></script>
# <script src="/js/lib/jquery-ui-multiselect/src/jquery.multiselect.js" type="text/javascript"></script>
# <script src="/js/lib/jquery-asPieProgress.js" type="text/javascript"></script><!-- svg pie chart -->
# <script src="/js/lib/jquery.bxslider/jquery.bxslider.min.js" type="text/javascript"></script>
# <script src="/js/lib/slick.min.js" type="text/javascript"></script>
# <!-- 웹접근성 개선 180501 추가 -->
# <script src="/js/lib/jquery.form.js" type="text/javascript"></script>
# <script src="/js/lib/validation/jquery.validate.js" type="text/javascript"></script>
# <script src="/js/lib/validation/additional-methods.js" type="text/javascript"></script>
# <script src="/js/lib/validation/messages_ko.js" type="text/javascript"></script>
# <script src="/js/lib/trimpath-template-1.0.38.js" type="text/javascript"></script>
# <script src="/js/comm/common.js" type="text/javascript"></script>
# <script src="/js/comm/dateUtils.js" type="text/javascript"></script>
# <script src="/js/comm/numberUtils.js?version=1.1" type="text/javascript"></script>
# <script src="/js/comm/stringUtils.js" type="text/javascript"></script>
# <script src="/js/comm/fileUtils.js" type="text/javascript"></script>
# <script src="/js/comm/validationUtils.js" type="text/javascript"></script>
# <script src="/js/akc.js" type="text/javascript"></script>
# <link href="/js/lib/jquery-autocomplete/jquery.autocomplete.css" rel="stylesheet" type="text/css"> <!-- jquery-autocomplete 2016/12/19 -->
# <script src="/js/lib/jquery-autocomplete/jquery-migrate-1.2.1.js" type="text/javascript"></script> <!-- jquery-autocomplete 2016/12/19 -->
# <script src="/js/lib/jquery-autocomplete/jquery.autocomplete.min.js " type="text/javascript"></script> <!-- jquery-autocomplete 2016/12/19 -->
# <script src="/js/makePCookie.js" type="text/javascript"></script> <!-- 웹로그 분석 -->
# <script src="/new_js/printThis/printThis.js" type="text/javascript"></script>
# <script src="/js/custom-hrdp.js?ver=11" type="text/javascript"></script>
# <script src="/new_js/lib/daterangepicker.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	/* 중복로그인 알람 */
# 	// 심사위원 OTP
#
#
#
#
# 	/* 우클릭 방지 */
# 	document.oncontextmenu = new Function("return false");
#
# 	/*
# 	// 소스보기 방지
# 	$(document).bind('keydown',function(e) {
# 		if (e.keyCode == 123) {
# 			e.preventDefault();
# 			e.returnValue = false;
# 		}
# 	});
# 	*/
#
# 	var strUrlArr = $(location).attr("pathname").split("/");
# 	var strIdx = strUrlArr.length-1;
# 	var strPrgIdArr = strUrlArr[strIdx].split(".");
# 	var prgId = strPrgIdArr[0];
# 	if(prgId!='PCTGO0100L'){
# 		//통합프로그램 설치 페이지는 적용 제외
# 		//전체 적용시 아래 주석 해제
# 		//document.write("<script type=\"text/javascript\" src=\"" +gfv_contextpath+"/markany/MaWebDRM.js\"></scr"+"ipt>");
# 	}
#
# 	/* 사용자 접속환경 체크 */
# 	fnCheckUserAgent() ;
#
# </script>
# <script src="/js/video_UC.js?ver=1.6" type="text/javascript"></script>
# <!-- webDRM -->
# <!-- 개별 설정시는 각 화면에 아래 주석 코드 붙혀넣기 후 주석 해제 -->
# <meta content="_csrf" name="_csrf_parameter"/><meta content="X-CSRF-TOKEN" name="_csrf_header"/><meta content="6b2051f8-e9ef-400e-8087-e5ad59c11313" name="_csrf"/>
# </link></link></link></head>
# <!--[if (IE 8)]>
# 	<script type="text/javascript" src="/js/lib/ie7-js/IE8.js"></script>
# 	<script type="text/javascript" src="/js/lib/css3-mediaqueries.js"></script>
# 	<script type="text/javascript" src="/js/lib/html5shiv.js"></script>
# 	<script type="text/javascript" src="/js/lib/selectivizr-1.0.2/selectivizr-min.js"></script>
# 	<script type="text/javascript" src="/js/lib/PIE/PIE_IE678.js"></script>
# <![endif]-->
# <body>
# <div id="skipnav">
# <a href="javascript:callContentWrapDo();" id="bodyNav" title="본문 바로가기">본문 바로가기</a>
# <a href="#gnb" id="gnbNav" title="주메뉴 바로가기">주메뉴 바로가기</a>
# <a href="#footerWrap" id="footerNav" title="푸터 바로가기">푸터 바로가기</a>
# </div>
# <div id="wrap">
# <style>
# .hd_span { display: block; z-index: -1;overflow: hidden;line-height: 0;text-indent: -9999px;}
# #myStateWrap .myStateArea .myStateBox .myState2 { width:173px; height:140px; margin:0 auto; text-align:center; border-left:1px #ebebec solid; }
# #myStateWrap .myStateArea .myStateBox .myState .text2 { font-size:18px; color:#4e4f51; padding-top:0px;  }
# #myStateWrap .myStateArea .myStateBox .myState .text3 { font-size:20px; color:#727476; }
# #myStateWrap .myStateArea .myStateBox .myState { padding-top:0px;   margin-top: 0px; margin-right:20px; }
# </style>
# <!-- 헤더영역 -->
# <header id="headerWrap">
# <div class="headerBtn verM" style="display:none">
# <!--div class="headerLogo"><a href="/"><img src="../newimages/common/headerLogo.png" alt="직업훈련포털 HRD-Net"></a></div-->
# <button class="backBtn btn" onclick="history.back();" type="button">이전 단계로 돌아가기</button>
# <button class="searhBtn btn" onclick="window.location.href = '/hrdp/co/pcoeo/PCOEO0100L.do'" type="button">검색</button>
# <button class="totalMenuBtn btn" type="button">전체메뉴</button>
# <button class="closeBtn btn" style="display:none" type="button">닫기</button>
# </div>
# <!-- 모바일 메뉴영역 -->
# <nav class="totalMenuWrap">
# <div class="overlay"></div>
# <div class="totalMenuArea">
# <div class="navHead">
# <div class="navLeftHead">
# <button class="loginBtn btn" id="loginBtnM" type="button">로그인</button>
# <button class="joinBtn btn" id="registBtnM" type="button">회원가입</button>
# </div>
# <div class="navLeftHead">
# <button class="closeTotalMenu btn" type="button">전체메뉴 닫기</button>
# </div>
# </div>
# <div class="navBody">
# <ul class="navDepthArea01">
# <li><a class="navDepth01_01 on" href="javascript:void(0);" title="훈련과정">훈련과정</a>
# <p class="navTitle">훈련과정</p>
# <ul class="navDepthArea02 sub01">
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=2" title="국민내일배움카드 훈련과정으로 이동">국민내일배움카드 훈련과정</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=6" title="K-디지털 트레이닝으로 이동">K-디지털 트레이닝</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=2&amp;kDgtlYn=Y" title="K-디지털 기초역량훈련으로 이동">K-디지털 기초역량훈련</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=8" title="중장년 새출발 카운슬링 과정으로 이동">중장년 새출발 카운슬링</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=2&amp;crseTracseSe=vist_octr_trng_yn|산업구조변화대응&amp;crseTracseSeNum=1" title="산업구조변화대응 특화훈련 훈련과정목록으로 이동">산업구조변화대응 특화훈련</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=3" title="기업 훈련과정으로 이동">기업 훈련과정</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=4" title="일학습병행과정으로 이동">일학습병행과정</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=5" title="정부부처별 훈련과정으로 이동">정부부처별 훈련과정</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=2&amp;bgrlInstYn=Y" title="유관기관 훈련과정으로 이동">유관기관 훈련과정</a></li>
# <li><a href="/hrdp/ti/ptiao/PTIAO0200L.do" title="STEP 이러닝으로 이동">STEP 이러닝</a></li>
# </ul>
# </li>
# <li style="display:none"><a class="navDepth01_02" href="javascript:void(0);" title="나의정보">나의정보</a>
# <p class="navTitle">나의정보</p>
# <ul class="navDepthArea02 sub02">
# </ul>
# </li>
# <li><a class="navDepth01_03" href="javascript:void(0);" style="top:310px" title="지원제도">지원제도</a>
# <p class="navTitle">지원제도</p>
# <ul class="navDepthArea02 sub03">
# <li><a href="/hrdp/gi/pgiao/PGIAO0300D.do" title="정부지원사업으로 이동">정부지원사업</a>
# <ul>
# <li><a href="/hrdp/gi/pgiao/PGIAO0200D.do" title="훈련안내 및 절차로 이동">훈련안내 및 절차</a></li>
# <li><a href="/hrdp/gi/pgiao/PGIAO0400D.do" title="훈련기관 유형 안내로 이동">훈련기관 유형 안내</a></li>
# </ul>
# </li>
# <li><a href="/hrdp/kc/pkcbo/PKCBO0100L.do" title="법정/서식/규정로 이동">법정/서식/규정</a>
# <ul>
# <li><a href="/hrdp/kc/pkcbo/PKCBO0100L.do" title="법령정보로 이동">법령정보</a></li>
# <li><a href="/hrdp/kc/pkcbo/PKCBO0200L.do" title="업무서식 및 규정로 이동">업무서식 및 규정</a></li>
# </ul>
# </li>
# <li><a href="/hrdp/di/pdiao/PDIAO0100L.do" title="범부처 신기술 훈련사업로 이동">범부처 신기술 훈련사업</a></li>
# <li><a href="/hrdp/gi/pgiho/PGIHO0100L.do" title="정부부처별 지원사업안내로 이동">정부부처별 지원사업안내</a></li>
# </ul>
# </li>
# <li><a class="navDepth01_04" href="javascript:void(0);" style="top:410px" title="일자리직업정보"> 일자리·<br/>직업정보</a>
# <p class="navTitle">일자리ㆍ직업정보</p>
# <ul class="navDepthArea02 sub04">
# <li><a href="/hrdp/ji/pjibo/PJIBO0100L.do" title="구인정보로 이동">구인정보</a></li>
# <li>
# <a class="on" href="/hrdp/ji/pjico/PJICO0100L.do" title="자격정보">자격정보</a>
# <ul>
# <li><a href="/hrdp/ji/pjico/PJICO0100L.do" onclick="" title="국가자격으로 이동">국가자격</a></li>
# <li><a href="/hrdp/ji/pjico/PJICO0200L.do" title="공인민간자격으로 이동">공인민간자격</a></li>
# <!-- <li><a href="/hrdp/ji/pjico/PJICO0300T.do" title="국가기술자격 시험일정으로 이동">국가기술자격 시험일정</a></li>-->
# </ul>
# </li>
# <li><a class="on" href="/hrdp/ji/pjido/PJIDO0100T.do" title="직업사전으로 이동">직업사전</a>
# <ul>
# <li><a href="/hrdp/ji/pjido/PJIDO0100T.do" title="직업사전소개로 이동">직업사전소개</a></li>
# <li><a href="/hrdp/ji/pjido/PJIDO0200T.do" title="직업사전검색으로 이동">직업사전검색</a></li>
# </ul>
# </li>
# <li><a class="on" href="/hrdp/ji/pjieo/PJIEO0100L.do" title="학과정보로 이동">학과정보</a>
# <ul>
# <li><a href="/hrdp/ji/pjieo/PJIEO0100L.do" onclick="" title="학과정보검색으로 이동">학과정보검색</a></li>
# <li><a href="/hrdp/ji/pjieo/PJIEO0200L.do" title="이색학과로 이동">이색학과</a></li>
# </ul>
# </li>
# <li><a href="/hrdp/ji/pjiao/PJIAO0100L.do" title="NCS분류체계로 이동">NCS분류체계</a></li>
# </ul>
# </li>
# <li><a class="navDepth01_05" href="javascript:void(0);" style="top:550px" title="고객센터">고객센터</a>
# <p class="navTitle">고객센터</p>
# <ul class="navDepthArea02 sub04">
# <li><a href="/hrdp/ct/pctdo/PCTDO0100L.do" title="자주묻는 질문으로 이동">자주묻는 질문</a></li>
# <li><a href="/hrdp/ct/pctco/PCTCO0100L.do" title="질문과 답변으로 이동">질문과 답변</a></li>
# <li><a href="/hrdp/sl/mslao/MSLAO0100D.do" title="내주변기관찾기으로 이동">내주변기관찾기</a></li>
# <li><a href="/hrdp/ct/pctfo/PCTFO0103D.do" title="범부처훈련기관 찾기으로 이동">범부처훈련기관 찾기</a></li>
# <li><a href="/hrdp/ct/pctao/PCTAO0100L.do" title="공지/행사 안내로 이동">공지/행사 안내</a></li>
# <li><a href="/hrdp/ct/pctbo/PCTBO0100L.do" title="이벤트/설문참여로 이동">이벤트/설문참여</a></li>
# </ul>
# </li>
# <li id="kdcdLi">
# <a class="navDepth01_06" href="/hrdp/pk/pkaao/PKAAO0100L.do" style="top:670px" title="K-디지털아카데미로 이동">
# <div class="kdg-gnb-bg">K-디지털<br/>아카데미</div>
# </a>
# </li>
# <li>
# <a class="navDepth01_07" onclick="moveTracseListPage(8)" style="top:870px" title="중장년 카운슬링으로 이동">
# <div class="kdg-gnb-bg">중장년<br/>카운슬링</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <!-- 모바일 메뉴영역 END-->
# <div class="headArea">
# <h1 class="logoTop"><a href="/" title="직업훈련포털 HRD-Net 로고">직업훈련포털 HRD-Net</a></h1>
# <div class="headTop">
# <ul id="tnb">
# <li><a href="/hrdp/mb/pmbao/PMBAO0100T.do" title="로그인으로 이동">로그인</a></li>
# <li><a href="/hrdp/mb/pmbbo/PMBBO0100D.do" title="회원가입으로 이동">회원가입</a></li>
# <li><a href="/hrdp/ct/pctdo/PCTDO0100L.do" title="고객센터로 이동">고객센터</a></li>
# <li><a href="/hrdp/hg/phggo/PHGGO0100D.do" title="HRD-Net 소개로 이동">HRD-Net 소개</a></li>
# <li><a href="http://as82.kr/keis/" target="_blank" title="새 창">원격지원</a></li>
# </ul>
# </div>
# <div class="headBot">
# <ul class="" id="gnb">
# <li><a class="" href="javascript:void(0);" title="훈련과정">훈련과정</a>
# <div class="gnbSubArea gnbSub01" style="display: none; height: 240px; padding-top: 0px; margin-top: 0px; padding-bottom: 0px; margin-bottom: 0px;">
# <ul>
# <li>
# <a href="javascript:void(0)" id="topMenu2___" onclick="moveTracseListPage(2)" title="국민내일배움카드 훈련과정으로 이동">국민내일배움카드 훈련과정</a><br/>
# <a href="javascript:void(0)" id="topMenu6___" onclick="moveTracseListPage(6)" title="K-디지털 트레이닝으로 이동">K-디지털 트레이닝</a><br/>
# <a href="javascript:void(0)" id="topMenu2_Y_" onclick="moveTracseListPage(2,'','Y')" title="K-디지털 기초역량훈련으로 이동">K-디지털 기초역량훈련</a>
# <a href="javascript:void(0)" id="topMenu8___" onclick="moveTracseListPage(8)" title="중장년 새출발 카운슬링">중장년 새출발 카운슬링</a>
# <a href="javascript:void(0)" id="topMenu2__1" onclick="moveTracseListPage(2,'','',1)" title="산업구조변화대응 특화훈련 훈련과정목록으로 이동">산업구조변화대응 특화훈련</a><br/>
# </li>
# <li>
# <a href="javascript:void(0)" id="topMenu3___" onclick="moveTracseListPage(3)" title="기업 훈련과정으로 이동">기업 훈련과정</a><br/>
# <a href="javascript:void(0)" id="topMenu4___" onclick="moveTracseListPage(4)" title="일학습병행과정으로 이동">일학습병행과정</a><br/>
# <a href="javascript:void(0)" id="topMenu5___" onclick="moveTracseListPage(5)" title="정부부처별 훈련과정으로 이동">정부부처별 훈련과정</a>
# </li>
# <li>
# <a href="javascript:void(0)" id="topMenu2Y__" onclick="moveTracseListPage(2, 'Y')" title="유관기관 훈련과정으로 이동">유관기관 훈련과정</a><br/>
# <a href="/hrdp/ti/ptiao/PTIAO0200L.do" title="STEP 이러닝으로 이동">STEP 이러닝</a>
# </li>
# </ul>
# </div>
# </li>
# <li><a class="" href="javascript:void(0);" title="지원제도">지원제도</a>
# <div class="gnbSubArea gnbSub02" style="display: none; height: 255px; padding-top: 0px; margin-top: 0px; padding-bottom: 0px; margin-bottom: 0px;">
# <ul>
# <li>
# <a href="/hrdp/gi/pgiao/PGIAO0300D.do" title="정부지원사업안내로 이동">정부지원사업안내</a>
# <ul class="navDepthArea02">
# <li><a href="/hrdp/gi/pgiao/PGIAO0300D.do" title="정부지원사업안내로 이동">정부지원사업안내</a></li>
# <li><a href="/hrdp/gi/pgiao/PGIAO0200D.do" title="훈련안내 및 절차로 이동">훈련안내 및 절차</a></li>
# <li><a href="/hrdp/gi/pgiao/PGIAO0400D.do" title="훈련기관 유형 안내로 이동">훈련기관 유형 안내</a></li>
# </ul>
# <a href="/hrdp/di/pdiao/PDIAO0100L.do" title="범부처 신기술 훈련사업으로 이동">범부처 신기술 훈련사업</a>
# <a href="/hrdp/gi/pgiho/PGIHO0100L.do" title="정부부처별 지원사업안내로 이동">정부부처별 지원사업안내</a>
# </li>
# <li>
# <a href="/hrdp/kc/pkcbo/PKCBO0100L.do" title="법령/서식/규정으로 이동">법령/서식/규정</a>
# <ul class="navDepthArea02">
# <li><a href="/hrdp/kc/pkcbo/PKCBO0100L.do" title="법령정보로 이동">법령정보</a></li>
# <li><a href="/hrdp/kc/pkcbo/PKCBO0200L.do" title="업무서식 및 규정으로 이동">업무서식 및 규정</a></li>
# </ul>
# </li>
# <li>
# <a href="/hrdp/gi/pgieo/PGIEO0300D.do" title="일학습병행으로 이동">일학습병행</a>
# <ul class="navDepthArea02">
# <li><a href="/hrdp/gi/pgieo/PGIEO0300D.do" title="일학습병행이란으로 이동">일학습병행이란</a></li>
# <li><a href="/hrdp/gi/pgieo/PGIEO0400D.do" title="운영기관으로 이동">운영기관</a></li>
# <li><a href="/hrdp/gi/pgieo/PGIEO0500L.do" title="자료공간으로 이동">자료공간</a></li>
# <li><a href="/hrdp/gi/pgieo/PGIEO0700D.do" title="외부평가로 이동">외부평가</a></li>
# <li><a href="/hrdp/gi/pgieo/PGIEO0600D.do" title="훈련과정개발보고서(PDMS)으로 이동">훈련과정개발보고서(PDMS)</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li><a class="" href="javascript:void(0);" title="일자리·직업정보">일자리·직업정보</a>
# <div class="gnbSubArea gnbSub03" style="display: none; height: 230px; padding-top: 0px; margin-top: 0px; padding-bottom: 0px; margin-bottom: 0px;">
# <ul>
# <li>
# <a href="/hrdp/ji/pjibo/PJIBO0100L.do" title="구인정보로 이동">구인정보</a><br/>
# <a href="/hrdp/ji/pjico/PJICO0100L.do" title="자격정보로 이동">자격정보</a>
# <ul>
# <li><a href="/hrdp/ji/pjico/PJICO0100L.do" title="국가자격으로 이동">국가자격</a></li>
# <li><a href="/hrdp/ji/pjico/PJICO0200L.do" title="공인민간자격으로 이동">공인민간자격</a></li>
# <!-- <li><a href="/hrdp/ji/pjico/PJICO0300T.do" title="국가기술자격 시험일정으로 이동">국가기술자격 시험일정</a></li> -->
# </ul>
# </li>
# <li><a href="/hrdp/ji/pjido/PJIDO0100T.do" title="직업사전으로 이동">직업사전</a>
# <ul>
# <li><a href="/hrdp/ji/pjido/PJIDO0100T.do" title="직업사전소개로 이동">직업사전소개</a></li>
# <li><a href="/hrdp/ji/pjido/PJIDO0200T.do" title="직업사전검색으로 이동">직업사전검색</a></li>
# </ul>
# </li>
# <li><a href="/hrdp/ji/pjieo/PJIEO0100L.do" title="학과정보로 이동">학과정보</a>
# <ul>
# <li><a href="/hrdp/ji/pjieo/PJIEO0100L.do" title="학과정보검색으로 이동">학과정보검색</a></li>
# <li><a href="/hrdp/ji/pjieo/PJIEO0200L.do" title="이색학과로 이동">이색학과</a></li>
# </ul>
# <a href="/hrdp/ji/pjiao/PJIAO0100L.do" title="NCS 분류체계로 이동">NCS 분류체계</a><br/>
# </li>
# </ul>
# </div>
# </li>
# <li><a href="javascript:void(0);" title="지식정보센터">지식정보센터</a>
# <div class="gnbSubArea gnbSub04">
# <ul>
# <li>
# <a href="/hrdp/kc/pkcfo/PKCFO0100L.do" title="인재뱅크로 이동">인재뱅크</a><br/>
# <a href="/hrdp/kc/pkceo/PKCEO0100L.do" title="스타훈련교사로 이동">스타훈련교사</a>
# </li>
# <li>
# <a href="/hrdp/ti/ptiio/PTIIO0100T.do" title="훈련기관평가정보로 이동">훈련기관평가정보</a>
# <ul>
# <li><a href="/hrdp/ti/ptiio/PTIIO0100T.do" title="집체훈련으로 이동">집체훈련</a></li>
# <li><a href="/hrdp/ti/ptiio/PTIIO0101T.do" title="원격훈련으로 이동">원격훈련</a></li>
# </ul>
# </li>
# <li>
# <a href="http://www.keis.or.kr/user/bbs/main/303/2118/bbsDataList.do" target="_blank" title="새창으로 열기">훈련/고용통계
# 									<img alt="외부링크" aria-hidden="true" src="/new_images/common/view.png" style="margin-left:4px;margin-top:-4px;"/>
# </a><br/>
# </li>
# </ul>
# </div>
# </li>
# <li class="kdg-nav-area">
# <a href="/hrdp/pk/pkaao/PKAAO0100L.do" id="kdgNav" style="left: -13px" title="K-디지털 아카데미로 이동">
# <span class="kdg-gnb-bg"></span><span class="txt">K-디지털 아카데미</span>
# </a>
# </li>
# <li class="kdg-nav-area">
# <a href="javascript:void(0);" id="kdgNav" onclick="moveTracseListPage(8)" title="중장년 새출발 카운슬링으로 이동">
# <span class="mdagCnsl_bg"></span><span class="txt">중장년 새출발 카운슬링</span>
# </a>
# </li>
# <li class="gnbSearchBtn">
# <a href="javascript:void(0);" title="검색">검색</a>
# <div class="gnbSubArea gnbSub06" style="display: none;">
# <ul class="searchArea">
# <li style="width:802px;">
# <form action="/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&amp;tracseTme=1&amp;crseTracseSe=C0061&amp;trainstCstmrId=500020018488" autocomplete="off" id="searchTotalForm" method="post" name="searchTotalForm">
# <fieldset>
# <legend>통합검색</legend>
# <label class="hide" for="searchTotalKeyword">검색어</label>
# <input id="searchTotalKeyword" name="searchTotalKeyword" placeholder="무엇을 찾으세요?" title="검색어" type="text" value=""/><button class="btnTotalSearch" id="btn_total_search" title="검색" type="button">검색</button>
# <div class="totalKeywordLst" id="totalKeywordLst" style="display:none;width:550px;margin:0 auto;">
# <ul></ul>
# </div>
# </fieldset>
# <div>
# <input name="_csrf" type="hidden" value="6b2051f8-e9ef-400e-8087-e5ad59c11313">
# </input></div></form>
# </li>
# <li class="searchKeywordArea" style="width:500px;">
# <p>인기검색어</p>
# <div class="searchKeyword">
# <a href="javascript:void(0);" onclick="fn_goTotalSearch('바리스타')" title="바리스타">#바리스타</a>
# <a href="javascript:void(0);" onclick="fn_goTotalSearch('컴퓨터')" title="컴퓨터">#컴퓨터</a>
# <a href="javascript:void(0);" onclick="fn_goTotalSearch('요양보호사')" title="요영보호사">#요양보호사</a>
# <a href="javascript:void(0);" onclick="fn_goTotalSearch('제빵')" title="제빵">#제빵</a>
# <a href="javascript:void(0);" onclick="fn_goTotalSearch('포토샵')" title="포토샵">#포토샵</a>
# </div>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <!-- //헤더영역 -->
# <!-- 메인 컨텐츠영역 -->
# <div id="contentWrap">
# <!-- 상단 비주얼 영역 -->
# <div class="" id="subTopWrap">
# <!-- 헤더 : mobile -->
# <!--  <div class="headerBtn">
#              div class="headerLogo"><a href="/"><img src="/new_images/common/headerLogo.png" alt="직업훈련포털 HRD-Net"></a></div
#              <button type="button" class="backBtn btn">이전 단계로 돌아가기</button>
#              <button type="button" class="searhBtn btn">검색</button>
#              <button type="button" class="totalMenuBtn btn">알림 서비스</button>
#              button type="button"class="closeBtn btn">닫기</button
#          </div>            -->
# <!-- //헤더 : mobile -->
# <div class="subTopArea">
# <h2 class="subTopTilte"></h2>
# <p class="subTopText"></p>
# </div>
# <div class="location">
# <!-- 2depth-->
# <ul id="locHref">
# <li class="goHome verPC"><a href="/" title="홈으로 이동">홈 </a></li>
# </ul>
# </div>
# </div>
# <div id="myStateWrap" style="display:none">
# <div class="myStateArea">
# <ul class="myStateBox">
# <li class="myState">
# <img alt="내사진" src="/new_images/common/imgMy.jpg" style="border:solid; border-radius:50%; width:29%; border: solid #727476 2px; "/>
# <p class="text1" id="myCstmrNm" style="display:inline"> 님 </p>
# <p class="text2"><span id="cardSe"><!-- 카드종류(내배카/구근카) --></span> <span id="myStatelmt"><!-- 유효기간빨간문구 --></span></p>
# <p class="text3" id="myIssuDe"><!-- 유효기간 --></p>
# <p class="text3" id="myIssuReport"><!--발급확인서 --></p>
# </li>
# <li class="myState2">
# <!-- IE 초점 시각적 인지 웹접근성 부분 웹 와치 대안으로 display Block 추가 20210812 -->
# <a href="/hrdp/ps/ppsvo/PPSVO0200L.do" style="display:block;" title="나의카드(이동)">
# <div class="icon01">
# <span class="hd_span">나의카드</span>
# </div>
# <p class="text1"><span class="color03">나의</span> 카드</p>
# <p class="text2"><span id="myState2"></span></p>
# </a>
# </li>
# <li class="myState2">
# <a href="/hrdp/ps/ppstc/PPSTC0115L.do" style="display:block;" title="나의 훈련진단상담(이동)">
# <div class="icon02"></div>
# <p class="text1"><span class="color03">나의</span> 훈련진단상담</p>
# <p class="text2">진단상담 <span id="faqCount">0건</span></p>
# </a>
# </li>
# <li class="myState2">
# <a href="/hrdp/ps/ppsco/PPSCO0100L.do" style="display:block;" title="나의훈련이력(이동)">
# <div class="icon03">
# <span class="hd_span">나의훈련이력</span>
# </div>
# <p class="text1"><span class="color03">나의</span> 훈련이력</p>
# <p class="text2">훈련수료 <span id="MytraHisCnt">0개</span></p>
# </a>
# </li>
# <li class="myState2">
# <a href="/hrdp/ps/ppsgo/PPSGO0100T.do" style="display:block;" title="나의관심(이동)">
# <div class="icon04">
# <span class="hd_span">나의관심 (훈련)</span>
# </div>
# <p class="text1"><span class="color03">나의</span> 관심 (훈련)</p>
# <p class="text2">맞춤훈련 <span id="myTrnCnt">0개</span></p>
# </a>
# </li>
# <li class="myState2">
# <a href="/hrdp/ps/ppswo/PPSWO0100L.do" style="display:block;" title="나의 수강신청이력(이동)">
# <div class="icon07">
# <span class="hd_span">나의 수강신청</span>
# </div>
# <p class="text1"><span class="color03">나의</span> 수강신청이력</p>
# <p class="text2">수강신청 <span id="MyRqutCnt">0개</span></p>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
# 	    var oper = "";
# 	    var operVer = "";
# 	    var appVerCode = "";
# 	    var userAgent = navigator.userAgent;
#
# 		var logintimer = setInterval(showLogintimer, 1000);
# 		function showLogintimer(){
# 			var tmpTime = $("#loginTimestampVal").val();
# 			//console.log(tmpTime);
# 			if(tmpTime == "") tmpTime = 0
# 			tmpTime = parseInt(tmpTime) + 1;
# 			$("#loginTimestampVal").val(tmpTime);
#
# 			var tmpMin = 0;
# 			var tmpSec = 0;
# 			tmpMin = Math.floor(tmpTime / 60);
# 			tmpSec = tmpTime - (tmpMin * 60);
#
# 			if(tmpMin >= 30){
# 				$("#logoutBtn").trigger("click");
# 				clearInterval(logintimer);
# 			}else{
# 				if(tmpSec >= 50){
# 					$("#loginTimestamp").html((29-tmpMin)+":0"+(59-tmpSec));
# 				}else{
# 					$("#loginTimestamp").html((29-tmpMin)+":"+(59-tmpSec));
# 				}
# 			}
# 		}
#
#         $(document).ready(
#
#             function() {
#             	if(location.href.indexOf("PCOBO0100P.do") > -1
#                         || location.href.indexOf("PCOCO0100P.do") > -1
#                         || location.href.indexOf("PCOBO0400P.do") > -1
#                         || location.href.indexOf("PCOCO0200P.do") > -1
#                 ){
#
#                 }else{
#
#                 }
#
#
#
#                 akcInit();
#                 /* var rankingUrl = gfv_contextpath + "/search/getRankings.do";
#
#                 if(isSecure == "true") {
#                     //rankingUrl = "http://" + serverName + serverPort + rankingUrl;
#                     //rankingUrl = "https://" + serverName + rankingUrl;
#                 } */
#
#                 $("#searchTotalKeyword").css("ime-mode", "active");
#
#                 $('.gnb>li:first-child ul').css('border-left',
#                     '1px solid #dbdbdb');
#
#                 // autocomplete
#                 /* $("#searchTotalKeyword").autocomplete([
#                     "내일배움카드",
#                     "고용노동부",
#                     "근로자 내일배움카드",
#                     "구직자 내일배움카드",
#                     "내일배움카드신청",
#                     "근로자 내일배움카드",
#                     "직장인 내일배움카드",
#                     "근로자 내일배움카드 신청",
#                     "내일배움",
#                     "내일배움카드제",
#                     "내일배움카드 발급",
#                     "근로자 내일배움카드 학원",
#                     "내일배움카드 근로자",
#                     "내일배움자격증센터"
#                     ],{
#                     matchContains: true,
#                     width: 384,
#                     scrollHeight: 400,
#                     cacheLength: 10
#                 }); */
#
#                 /* $('#searchTotalKeyword').keyup(function(e){
#                     $.ajax({
#                         url: '/search/autocomplete.do',
# 						type: 'POST',
# 						data: {
# 							searchTotalKeyword: $("#searchTotalKeyword").val(),
# 						},
# 						success: function(data) { // submit 성공 시
# 							//console.log("success");
# 							var arr = new Array();
# 							var i = 0;
# 							$(data.list).each(function(idx,item) {
# 								arr[i] = item;
# 								//console.log(arr[i]);
#
# 								i++;
# 					        });
#
# 							$("#searchTotalKeyword").autocomplete(arr,{
# 				           		matchContains: true,
# 				           		width: 384,
# 				           		scrollHeight: 400,
# 				           		cacheLength: 10,
# 				           		select : function(event, ui) {
# 				           			console.log("success");
# 				           		}
# 				           	});
# 						},
# 						error: function(data){ // submit 실패 시
# 				//				alert("Error");
# 						}
# 					});
#
# 					if(e.keyCode == 13) {
# 						$('#btn_total_search').click();
# 						return false;
# 					}
# 				});   */
# 				document.addEventListener("deviceready", onDeviceReady, false);
# 				function onDeviceReady() {
# 					if(typeof(device) != 'undefined' && typeof(device.platform) != 'undefined' ) {
# 						oper = device.platform;
# 						operVer = device.version;
# 						appVerCode = device.appVersionCode;
# 					}
# 				}
#
# 				$("#loginTimestampReflash").on("click", function() {
# 		    		$.ajax({
# 		    			url : '/hrdp/mb/pmbao/reloadPage.do',
# 		    			dataType : "json",
# 		    			type : 'POST',
# 		    			success : function(data) {
# 							$("#loginTimestampVal").val(0);
# 		    			},
# 		    			error : function(data) {
# 		    				alert("정상적으로 처리할 수 없습니다.\n다시 시도해주시기 바랍니다.");
# 		    			}
# 		    		});
# 				});
#             });
#
#
#
#         var d = new Date();
#         var week = ['일', '월', '화', '수', '목', '금', '토'];
#         var year = d.getFullYear();
#         var month = d.getMonth() + 1;
#         var day = d.getDate();
#         var day2 = d.getDay();
#
#         /* *********************************************
#          * 2017.10.11 이상민 수정
#          * 자바스크립트 숫자형형식 문자열로 변경
#          * *********************************************/
#         year = "" + year;
#         month = (month < 10) ? "0" + month : "" + month;
#         day = (day < 10) ? "0" + day : "" + day;
#
#         var full = year + "-" + month + "-" + day;
#         var checkDay = year + "" + month + "" + day;
#
#         /* ****************************************************
#          if((""+month).length == 1){month = "0"+month};
#          if((""+day).length == 1){day = "0"+day};
#
#          var full = year+"-"+month+"-"+day;
#          var checkDay = year+month+day;
#          * ******************************************************/
#
#         $("#dnjf").empty().append(full.substr(5, 2));
#         $("#dlf").empty().append(full.substr(8, 2));
#         $("#dydlf").empty().append(week[d.getDay()]);
#         var currentWeek = d.getDay();
#         var bxs;
#         function gotoScrollTop() {
#             $('body,html').animate({
#                 scrollTop : 0
#             }, 500);
#             return false;
#         }
#
#
#
#
#         $(function() {
#             findDay();
#
#
#             /* 웹접근성 개선 180501 수정 */
#             /*
#             bxs = $('.bxv').bxSlider({
#                 mode: 'vertical',
#                 auto: true,
#                 infiniteLoop: false,
#                 autoHover : true,
#                 controls : false,
#                 pager:false
#             });
#              */
#
#             /* var deadlineUrl = gfv_contextpath + "/search/deadlineTracse.do";
#
#             if(isSecure == "true") {
#                 //deadlineUrl = "http://" + serverName + serverPort + deadlineUrl;
#                 //deadlineUrl = "https://" + serverName + deadlineUrl;
#             } */
#
#             //2017/01/30 수정됨
#             // bxslider 삭제 웹접근성 개선 180501
#             /*$('.bxpause').click(function(){
#                 bxs.stopAuto();
#                 $(this).hide();
#                 $('.play').show();
#                 $("#bxvstat").val("P");
#             });
#             $('.play').click(function(){
#                 bxs.startAuto();
#                 $(this).hide();
#                 $('.bxpause').show();
#                 $("#bxvstat").val("S");
#             });
#             $('.prev').click(function(){
#                 bxs.goToPrevSlide();
#             });
#             $('.next').click(function(){
#                 bxs.goToNextSlide();
#             });
#              */
#
#             /* var menuUrl = gfv_contextpath + "/hrdp/co/pcoxo/selectGnbMenuList.do";
#
#             if(isSecure == "true") {
#                 //menuUrl = "http://" + serverName + serverPort + menuUrl;
#                 //menuUrl = "https://" + serverName + menuUrl;
#             } */
#
#             var $targetUl = $("div.gnb_area>ul.gnb");
#             if("PC" == "PC") {
# 	            $.ajax({
# 	                url : "/hrdp/co/pcoxo/selectGnbMenuList.do",
# 	                //url: menuUrl,
# 	                type : 'POST',
# 	                async : false,
# 	                data : {},
# 	                dataType : "json",
# 	                //dataType: "jsonp",
# 	                //jsonp: "callback",
# 	                success : function(data) {
# 	                    var menuList = data.menuList;
# 	                    //window.console.log(JSON.stringify(menuList));
# 	                    $
# 	                        .each(
# 	                            menuList,
# 	                            function(v, i) {
# 	                                //window.console.log(i.menuNm);
# 	                                if (i.menuLvl == 1) {
# 	                                    $targetUl
# 	                                        .append('<li><h2><a href="javascript:void(0);">'
# 	                                            + i.menuNm
# 	                                            + '</a></h2><ul id="GNB_' + i.menuId + '"></ul></li>'); //웹접근성 개선 180406
#
# 	                                } else if (i.menuLvl == 2) {
# 	                                    var progrmUrlAdres = i.progrmUrlAdres ? ("/" + i.progrmUrlAdres)
# 	                                        : "#";
#
# 	                                    // (시작) 17.09.20 박태영 지식센터 > 훈련/통계 메뉴만 새창으로 나오게 추가
# 	                                    var targetB = "";
# 	                                    if (progrmUrlAdres == "/hrdp/kc/pkcao/PKCAO0100L.do") {
# 	                                        targetB = ' target="_blank"';
# 	                                    }
# 	                                    // (끝) 17.09.20 박태영
#
# 	                                    $("#GNB_" + i.upperMenuId,
# 	                                        $targetUl).append(
# 	                                        '<li><a href="' + progrmUrlAdres + '"' + targetB + '>'
# 	                                        + i.menuNm
# 	                                        + '</a></li>');
# 	                                }
# 	                            });
# 	                },
# 	                error : function(data) {
# 	                    //alert("GnbMenu Error!!!");
# 	                }
# 	            });
#         	}
#
#             // Gnb
#             if (typeof ('.gnb') !== "undefined") {
#                 var max = 0;
#                 var flag = 0;
#                 $('.gnb>li>ul').each(function() {
#                     var h = $(this).outerHeight();
#                     max = Math.max(max, h);
#                 });
#
#                 $('.gnb>li>h2>a').bind('focusin mouseenter', function() {
#                     $('.gnb>li>ul').css('height', max);
#                     $('.gnb>li').removeClass();
#                     $(this).parent().parent('li').addClass('on');
#                     if (flag == 0) {
#                         flag = 1;
#                         $('.gnb li ul').stop().slideDown();
#                         $('.gnb_area').stop().animate({
#                             'height' : max + 53
#                         });
#                     }
#                 });
#                 $('.gnb>li>ul').bind('focusin mouseenter', function() {
#                     $('.gnb>li').removeClass();
#                     $(this).parent('li').addClass('on');
#                 });
#                 $('.gnb_area').bind('mouseleave', function() {
#                     $('.gnb>li').removeClass();
#                     if (flag == 1) {
#                         flag = 0;
#                         $('.gnb li ul').stop().slideUp();
#                         $('.gnb_area').stop().animate({
#                             'height' : 50
#                         });
#                     }
#                 });
#                 $('.gnb>li:last-child>ul>li:last-child').bind('focusout', function() {
#                     if (flag == 1) {
#                         flag = 0;
#                         $('.gnb>li').removeClass();
#                         $('.gnb li ul').stop().slideUp();
#                         $('.gnb_area').stop().animate({
#                             'height' : 50
#                         });
#                     }
#                 });
#                 //이 오브젝트로 왔을때 메뉴 접음(이 오브젝트와 메뉴 사이에 새 오브젝트가 생길경우 새 오브젝트에 함수 적용)
#                 $('.process_info .next').bind('focusin', function(){
#                     if (flag == 1) {
#                         flag = 0;
#                         $('.gnb>li').removeClass();
#                         $('.gnb li ul').stop().slideUp();
#                         $('.gnb_area').stop().animate({
#                             'height' : 50
#                         });
#                     }
#                 });
#             }
#
#
#
#             /*
#             var max = 0;
#             var flag = 0;
#             $('.gnb>li>ul').each(function(){
#                 var h = $(this).outerHeight();
#                 max = Math.max(max, h);
#             });
#
#             $('.gnb>li>h2>a').bind('focusin mouseenter', function() {
#                 $('.gnb>li>ul').css('height',max);
#                 $('.gnb>li').removeClass();
#                 $(this).parent().parent('li').addClass('on');
#                 if(flag==0){
#                     flag = 1;
#                     $('.gnb li ul').stop().slideDown();
#                     $('.gnb_area').stop().animate({'height':max+57});
#                 }
#             });
#             $('.gnb>li>ul').bind('focusin mouseenter', function() {
#                 $('.gnb>li').removeClass();
#                 $(this).parent('li').addClass('on');
#             });
#             $('.gnb_area').bind('mouseleave', function() {
#                 $('.gnb>li').removeClass();
#                 if(flag==1){
#                     flag = 0;
#                     $('.gnb li ul').stop().slideUp();
#                     $('.gnb_area').stop().animate({'height':54});
#                 }
#             });
#             $('.gnb>li:last-child>ul>li:last-child').bind('focusout', function() {
#                 $('.gnb li ul').stop().slideUp();
#                 $('.gnb_area').stop().animate({'height':54});
#             });*/
#
#             //Go to top
#             if (typeof ('.top') !== "undefined") {
#                 $('a.top').bind('click', function() {
#                     gotoScrollTop();
#                 });
#             } /* 웹접근성 개선 180502 : 태그 변경 */
#
#             $('#btn_total_search').click(function() {
#                 var searchTotalKeyword = $("#searchTotalKeyword").val();
#
#                 if (searchTotalKeyword == "") {
#                     alert("검색어를 입력해 주세요.");
#                     return;
#                 }
#
#                 var url = "/hrdp/co/pcoeo/PCOEO0100T.do";
#
#                 $('#searchTotalForm').prop("action", url);
#                 $("#searchTotalForm").prop("method", "get");
#                 $('#searchTotalForm').submit();
#
#                 //var param = "?searchTotalKeyword=" + searchTotalKeyword + "&currentTab=1";
#
#                 //location.href = "/hrdp/co/pcoeo/PCOEO0100T.do" + param;
#             });
#             /*
#             $('#loginBtn').click(function() {
#
#                 var Server_Ip = window.location.host;
#
# 	            if( Server_Ip.indexOf("www.hrd.go.kr") > -1){
# 	                if(document.location.protocol !='https:'){
# 	                    location.href = "https://www.hrd.go.kr/hrdp/mb/pmbao/PMBAO0100T.do";
# 	                }else{
# 	                    location.href = "/hrdp/mb/pmbao/PMBAO0100T.do";
# 					}
# 				} else{
# 					location.href = "/hrdp/mb/pmbao/PMBAO0100T.do";
# 				}
#
# 			});
# 		 */
# 			 $('#searchTotalKeyword').keypress(function(e) {
# 	             if (e.keyCode == 13) {
# 	                 $('#btn_total_search').click();
# 	                 return false;
# 	                 //location.href = "/hrdp/co/pcoeo/PCOEO0100T.do";
# 	             }
# 	             $(this).closest(".gnbSubArea").css("height","auto");
#
# 	         });
#
# 	         $('#searchTotalKeyword').focus(function(e) {
# 	             $(this).closest(".gnbSubArea").css("height","auto");
# 	         });
#
#             $('#authtyCdServiceLink').click(
#                 function() {
#                     $("#authorityDiv").load(
#                         "/hrdp/mb/pmbao/PMBAO0100P.do");
#                     $('body').addClass('no_scroll');
#                     //$self=$(this);
#                     $('#authorityPopup').focus();
#                 });
#
#             /* $('#remoteServiceLink').click(function() {
#                 alert('원격지원시스템');
#             }); */
#
#             $("#adminServiceLink1, #adminServiceLink2").on("click",
#                 function() {
#                     var mberSe = "";
#                     var loginConectMthCd = "";
#                     var ogcrPkValueStatcd = "";
#
#                     if (loginConectMthCd == "B") {
#                         if ("C0178" == mberSe) {
#                             location.href = "/hrdp/pa/ppaao/PPAAO0100D.do";
#                         } else if ("C0180" == mberSe
#                             || "C0261" == mberSe) {
#                             location.href = "/hrdp/ca/pcaao/PCAAO0100D.do";
#                         } else {
#                             alert('공동인증서로 로그인후 사용가능합니다');
#                         }
#
#                         /* }else if(ogcrPkValueStatcd == 0){
#                             alert('공동인증서 등록 후 사용 가능합니다.');
#                             location.href ='/hrdp/mb/pmbdo/PMBDO0200D.do'; */
#                     } else {
#                         //alert('공동인증서 로그인후 사용가능합니다');
#                         alert('공동인증서 로그인 후 사용가능합니다.\n공동인증서를 등록하지 않은  경우\n나의 정보> 공동인증서 등록/변경 메뉴에서 공동인증서를 등록하신 후에\n공동인증서로 다시 로그인하시기 바랍니다.');
#
#                         /* ****************************************************
#                          * 2017.05.11 이상민
#                          * SSL 문제로 임시로 공동인증서 등록페이지로 돌림
#                          * ****************************************************/
#                         if (mberSe == 'C0178') { // 개인인 경우
#                             location.href = '/hrdp/mb/pmbdo/PMBDO0200D.do';
#                         } else { // 사업주( 훈련기관 없음 )
#                             location.href = '/hrdp/mb/pmbdo/PMBDO0200D.do';
#                         }
#
#                         wpopup(
#                             '/hrdp/mb/pmbao/PMBAO0106P.do',
#                             815, 620, 'PMBAO0106P');
#                     }
#
#                 });
#
#             $("#aSiteMap").click(function() {
#                 $("#sitemap").fadeIn("100");
#             });
#
#             $("#closeSiteMap").click(function() {
#                 $("#sitemap").fadeOut("100");
#             });
#
#         });
#
#
#
#         function fn_bxvfocusin() {
#             bxs.stopAuto();
#         }
#
#         function fn_bxvfocusout() {
#
#             if ($("#bxvstat").val() != "P") {
#                 bxs.startAuto();
#             }
#             bxs.reloadSlider();
#         }
#
#         function fn_getUrlData(url) {
#             location.href = url;
#         }
#         /* function openImbakPop(_tracseId, _tracseTme){
#          var data = {tracseId : _tracseId, tracseTme : _tracseTme}
#          $("#imbak").load('/hrdp/co/pcobo/PCOBO0100P.do',data);
# 	 } */
#
#         function findDay(gbn) {
#
#             if (gbn == "prev") {
#                 var increaseDate = gfn_addDate(full, -1);
#                 full = increaseDate;
#                 $("#dnjf").empty().append(full.substr(5, 2));
#                 $("#dlf").empty().append(full.substr(8, 2));
#                 currentWeek = currentWeek - 1;
#                 if (currentWeek < 0) {
#                     currentWeek = 6;
#                 }
#                 $("#dydlf").empty().append(week[currentWeek]);
#             }
#             if (gbn == "next") {
#                 var increaseDate = gfn_addDate(full, 1);
#                 full = increaseDate;
#                 $("#dnjf").empty().append(full.substr(5, 2));
#                 $("#dlf").empty().append(full.substr(8, 2));
#                 //$("#dydlf").empty().append(week[d.getDay()+1]);
#                 currentWeek = currentWeek + 1;
#                 if (currentWeek > 6) {
#                     currentWeek = 0;
#                 }
#                 $("#dydlf").empty().append(week[currentWeek]);
#             }
#         }
#
#         function fn_goTotalSearch(searchTotalKeyword) {
#             $("#searchTotalKeyword").val(searchTotalKeyword);
#
#             var url = "/hrdp/co/pcoeo/PCOEO0100T.do";
#
#             $('#searchTotalForm').prop("action", url);
#             $("#searchTotalForm").prop("method", "get");
#             $('#searchTotalForm').submit();
#         }
#
#         $("#loginBtnM").click(function() {
#             location.href = "/hrdp/mb/pmbao/PMBAO0100T.do";
#         });
#         $("#registBtnM").click(function() {
#             location.href = "/hrdp/mb/pmbbo/PMBBO0100D.do";
#         });
#
#         $("#logoutBtn, #logoutBtnM").click(function() {
#             // 모바일앱 비콘 서비스 실행 중인 경우, 로그아웃시 비콘 서비스 종료
#             if (userAgent.indexOf('HRD-NET-APP/2.2') > -1 && (oper == "Android" || oper == "iOS") && appVerCode >= 21010) {
#                 beacon.getServiceStatus(function(data) {
#                     if (data == "true") {
#                         beacon.setServiceStatus("stop");
#                     }
#                 });
#             }
#             var snsGbn = "";
#
#             if(snsGbn == "NAVER_LOGIN"){
#                 fn_naverLogoutPopup();
#             }else{
#                 fn_logoutMove();
#             }
#         });
#
#         function fn_naverLogoutPopup(){
#             location.href = "https://nid.naver.com/nidlogin.logout";
#
#             setTimeout (function () {fn_logoutMove();}, 2000);
#         }
#
#         function fn_logoutMove() {
#             location.href = "/hrdp/mb/pmbao/logout.do";
#         }
#
#
#
#         function moOgcrUseChk(ogcrUseYn, urlAdres, auth) {
#     		$.ajax({
#     			url : '/hrdp/mb/pmbao/selectTbHwbp1001mtUserLoginConectMthCd.do',
#     			dataType : "json",
#     			type : 'POST',
#     			success : function(data) {
#                     var di = "PC";
#     	            if (data.loginConectMthCd) {
#     	            	var authYn = (data.loginConectMthCd == "B" || data.loginConectMthCd == "D") ? true : false;
#                    		if (ogcrUseYn == "Y") {
#                    			if (authYn) {
#                    				location.href = urlAdres;
#                    			} else {
#                    				if (di == "APP") {
#         	               			$.modal.infoBox("<span style='color:#DA5601; text-decoration-line:underline;'>*간편인증 로그인 또는 공동인증서 로그인</span>을 통해 이용 가능한 서비스입니다.<br/><br/><span style='color:#DA5601; text-decoration-line:underline;'>간편인증이 실패시 나의정보 > 회원정보관리 > 본인인증을 진행 후 다시 시도해주시기 바랍니다.</span>", moGoLoginPage, urlAdres);
#                    				} else {
#                    					$.modal.infoBox("<span style='color:#DA5601; text-decoration-line:underline;'>*간편인증 로그인</span>을 통해 이용 가능한 서비스입니다.<br/><br/><span style='color:#DA5601; text-decoration-line:underline;'>간편인증이 실패시 나의정보 > 회원정보관리 > 본인인증을 진행 후 다시 시도해주시기 바랍니다.</span>", moGoLoginPage, urlAdres);
#                					}
#                    			}
#                    		} else {
#                    			location.href = urlAdres;
#                    		}
#                    	} else {
#                    		if (data.fail == "mberSe") {
#     	               		$.modal.alertBox("개인회원만 이용 가능합니다.");
#     	               	} else {
#     	               		if (di == "APP") {
#     	               			$.modal.infoBox("<span style='color:#DA5601; text-decoration-line:underline;'>*간편인증 로그인 또는 공동인증서 로그인</span>을 통해 이용 가능한 서비스입니다.<br/><br/><span style='color:#DA5601; text-decoration-line:underline;'>간편인증이 실패시 나의정보 > 회원정보관리 > 본인인증을 진행 후 다시 시도해주시기 바랍니다.</span>", moGoLoginPage, urlAdres);
#                				} else {
#                					$.modal.infoBox("<span style='color:#DA5601; text-decoration-line:underline;'>*간편인증 로그인</span>을 통해 이용 가능한 서비스입니다.<br/><br/><span style='color:#DA5601; text-decoration-line:underline;'>간편인증이 실패시 나의정보 > 회원정보관리 > 본인인증을 진행 후 다시 시도해주시기 바랍니다.</span>", moGoLoginPage, urlAdres);
#            					}
#     	               	}
#                    	}
#     			},
#     			error : function(data) {
#     				alert("정상적으로 처리할 수 없습니다.\n다시 시도해주시기 바랍니다.");
#     				location.reload();
#     			}
#     		});
#     	}
#
#     	function moGoLoginPage(urlAdres) {
#     		var url = "/hrdp/mb/pmbbo/PMBBO0500T.do";
#     		var sUrl = url+"?urlAdresOri="+encodeURIComponent(urlAdres);
#     		location.href = sUrl;
#     	}
#
#         //훈련기관 상세보기
#         /* function fn_main1_trainstInfo(_tracseId, _tracseTme, _trainstCstmrId){
#          var url = "/hrdp/co/pcoco/PCOCO0100P.do";
# 	 var parameter = {};
# 	 parameter.tracseId = _tracseId;
# 	 parameter.tracseTme = _tracseTme;
# 	 parameter.trainstCstmrId = _trainstCstmrId;
#
# 	 gfn_openDialog(url, parameter);
# 	 }
#
# 	 //훈련과정 상세보기
# 	 function fn_viewTracseInfo(_tracseId, _tracseTme){
# 	 var url = "/hrdp/co/pcobo/PCOBO0100P.do";
# 	 var parameter = {};
# 	 parameter.tracseId = _tracseId;
# 	 parameter.tracseTme = _tracseTme;
#
# 	 gfn_openDialog(url, parameter);
# 	 }
#
# 	 function fn_viewTrainstInfo(_tracseId, _tracseTme, _trainstCstmrId) {
# 	 var param = "?tracseId=" +_tracseId + "&tracseTme=" + _tracseTme + "&trainstCstmrId=" + _trainstCstmrId;
#
# 	 wpopup("/hrdp/co/pcoco/PCOCO0100P.do" + param, 1000, 620, 'trainstInfo');
# 	 //gfn_openDialog(url, parameter);
# 	 }
# 	 */
#     </script>
# <div id="subContentWrap">
# <!-- 좌측 메뉴 영역 -->
# <div class="lnbArea">
# <ul class="snb">
# </ul>
# </div>
# <!--// 좌측 메뉴 영역 -->
# <form action="/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&amp;tracseTme=1&amp;crseTracseSe=C0061&amp;trainstCstmrId=500020018488" id="ogcrLoginScrinForm" method="post" name="ogcrLoginScrinForm">
# <input id="urlAdresOri" name="urlAdresOri" type="hidden" value=""/>
# <div>
# <input name="_csrf" type="hidden" value="6b2051f8-e9ef-400e-8087-e5ad59c11313"/>
# </div></form>
# <form action="/hrdp/ps/ppsvo/PPSVO0200R.do" id="menu_printFrm" method="post" name="printFrm">
# <input name="cstmrId" type="hidden" value=""/>
# <input name="flcNo" type="hidden"/>
# <div>
# <input name="_csrf" type="hidden" value="6b2051f8-e9ef-400e-8087-e5ad59c11313"/>
# </div></form>
# <script type="text/javascript">
#
# 	$(function() {
#
#
#
# 		var pathname = document.location.pathname;
# 		var urlAdresOri  = $("#urlAdresOri").val();
#
# ...
# <p class="copyright">
# <span class="verPC">Copyright ⓒ 2016. Human Resources Development Service Of Korea. All Rights Reserved.</span>
# <span class="verM">HRD-Net 시스템관련문의 <strong style="color:#c74b00;">1577-7114(유료)</strong>, 고용노동부<strong style="color:#c74b00;">1350(유료)</strong></span>
# <span class="verM">Copyright ⓒ 고용노동부 한국고용정보원 all rights reserved.</span>
# </p>
# </div>
# </footer>
# <div class="fixBotNav verM" id="floatingWrap">
# <nav class="floatingMenu">
# <ul>
# <li class="home on"><a href="/" title="홈으로 이동"><span>홈</span></a></li>
# <li class="search"><a href="/hrdp/ti/ptiao/PTIAO0100L.do?pageId=2" title="과정검색"><span>과정검색</span></a></li>
# <li class="my"><a href="javascript:void(0)" onclick="fn_myMove();return false;" title="내 정보로 이동"><span>나의 정보</span></a></li>
# <li class="help"><a href="#tutorial-section" role="button" title="도움말보기"><span>도움말</span></a></li><!-- 1030 메뉴추가 -->
# </ul>
# </nav>
# </div>
# <!-- 1103 공유하기 아이콘 -->
# <!-- 1103 공유하기 아이콘 //-->
# <script>
#     if(location.href.indexOf("/hrdp/gi/pgiao/") > -1){
#
#     }else{
#         $(".btn-share-in").hide();
#     }
#
# </script>
# <!-- 1030 공유하기 레이어팝업  -->
# <article class="common-popup popup-step share-in" style="display: none;">
# <div class="common-popup-inner">
# <div class="header">
# <h1 class="title">공유하기</h1>
# <button class="btn-close" type="button"><span>닫기</span></button>
# </div>
# <div class="content">
# <ul class="sharein-list">
# <li><a class="facebbok" href="javascript:void(0);"><img alt="페이스북" src="/new_images/common/ico-sharein-fb.png"/></a></li>
# <li><a class="twitter" href="javascript:void(0);"><img alt="트위터" src="/new_images/common/ico-sharein-tw.png"/></a></li>
# <!-- <li><a href="javascript:sendLink();" id="kakao-link-btn"><img src="/new_images/common/ico-sharein-kakao.png" alt="카카오톡" /></a></li> -->
# <li><a class="url-copy" href="#"><img alt="URL공유" src="/new_images/common/ico-sharein-url.png"/></a></li>
# <li><a href="javascript:sendSMS();"><img alt="이메일보내기" src="/new_images/common/ico-sharein-email.png"/></a></li>
# <!-- <li><a href="javascript:moreSNS();"><img src="/new_images/common/ico-sharein-more.png" alt="더보기" /></a></li> -->
# </ul>
# <div class="url-copy-info" style="display: none;">
# <label class="label" for="copy_url" style="display:block; margin-left:1em; margin-right:1em;">URL을 복사할 수 있습니다.</label>
# <input class="input-url" id="copy_url" name="copy_url" title="복사  URL 정보" type="text" value="">
# <button class="btnType2 btn-copy" id="copy_url_btn" type="button">선택</button>
# </input></div>
# </div>
# </div>
# </article>
# <!-- 1030 공유하기 레이어팝업  //-->
# <script>
#     function sendSMS(){
#     	var device_info = "PC";
#
# 		if(device_info == 'iPhone') location.href = "sms:" + "&body=" + location.href;
# 		else location.href = "sms:" + "?body=" + location.href;
#     }
#
#     function moreSNS(){
#         if(navigator.share){
#             navigator.share({
#                 title:"HRD-Net",
#                 text: $(".headingTitle").text(),
#                 url: location.href,
#             })
#             .then(() => alert(0))
#             .catch((error) => alert(error));
#         }else{
#             alert("nn");
#         }
#
#     }
# </script>
# <script language="javascript" type="text/javascript">
#     function fn_myMove(){
#          // 로그인
#             location.href="/hrdp/mb/pmbao/PMBAO0100T.do";
#
#
#
#
#     };
#
#     // moelSTKN form 전송
#     function fn_moelSTKN(url){
# 		var moelSTKN = "";
# 		//if(moelSTKN != null && moelSTKN != "") url = url + "?moelSTKN=" + moelSTKN;
#
# 		var deviceInfo = "PC";
# 		if(gfn_isNull(deviceInfo)) deviceInfo = "PC";
#
# 		if(deviceInfo == "PC"){
# 			window.open(url, 'ssoLinkOpen');
#
# 			var ssoForm = $('<form id="ssoForm" method="post"></form>');
# 			var  csrfVar = $('meta[name="_csrf"]').attr('content');
# 			$('body').append(ssoForm);
# 			$("#ssoForm").append("<input name='_csrf' value='" + csrfVar + "' type='hidden'>");
# 			$("#ssoForm").append("<input name='moelSTKN' value='" + moelSTKN + "' type='hidden'>");
#
# 			$("#ssoForm").attr("action", url).attr("target", "ssoLinkOpen").submit();
# 		}else{
# 			// APP에서 사용 될 수 있도록 분기
# 			goWorkNet2(url, moelSTKN);
# 		}
# 	}
#
#     function fn_moelSTKNkud(){
#     	var url = 'https://www.kua.go.kr/login/ssoLink.do';
#     	$.ajax({
#     		url : "/hrdp/mb/pmbao/getKudSSO.do"
#       	  , type : 'POST'
#     	  , data : {}
#     	  , dataType : "json"
#     	  , success : function(data) {
# 	   	       	url = data.url;
# 	   	       	var moelSTKN = data.simpleToken;
# 	   	       	//if(moelSTKN != null && moelSTKN != "") url = url + "?moelSTKN=" + moelSTKN;
#
# 	   	       	var deviceInfo = "PC";
# 	   	       	if(gfn_isNull(deviceInfo)) deviceInfo = "PC";
# 	   	       	if(deviceInfo == "PC"){
# 	   	       		window.open(url, 'ssoLinkOpen');
#
# 	   				var ssoForm = $('<form id="ssoForm" method="post"></form>');
# 	   				var  csrfVar = $('meta[name="_csrf"]').attr('content');
# 	   				$('body').append(ssoForm);
# 	   				$("#ssoForm").append("<input name='_csrf' value='" + csrfVar + "' type='hidden'>");
# 	   				$("#ssoForm").append("<input name='moelSTKN' value='" + moelSTKN + "' type='hidden'>");
#
# 	   				$("#ssoForm").attr("action", url).attr("target", "ssoLinkOpen").submit();
#
# 	   	       	}/*else{
# 	   	       		// APP에서 사용 될 수 있도록 분기
# 	   	       		goWorkNet2(url);
# 	   	       	}*/
#     	  	}
#     	  , error : function(data) {
# 			console.log(data);
#   	  		}
#     	  });
#
# 	}
#
#     function goWorkNet2(linkUrlAdres, moelSTKN) {
#        	var url = (checkUrlForm(linkUrlAdres));
#        	if (navigator.userAgent.indexOf('HRD-NET-APP/2.2') > -1) {
#        		if (device.platform == 'iOS') {
#        			cordova.InAppBrowser.open(url,"_system");
#        		} else if (device.platform == 'Android'){
#        			navigator.app.loadUrl(url, {openExternal: true});
#        		}
#        	} else {
#        		// 모바일 웹 인경우 세창 이동
#        		window.open(url, 'ssoLinkOpen');
#
# 			var ssoForm = $('<form id="ssoForm" method="post"></form>');
# 			var  csrfVar = $('meta[name="_csrf"]').attr('content');
# 			$('body').append(ssoForm);
# 			$("#ssoForm").append("<input name='_csrf' value='" + csrfVar + "' type='hidden'>");
# 			$("#ssoForm").append("<input name='moelSTKN' value='" + moelSTKN + "' type='hidden'>");
#
# 			$("#ssoForm").attr("action", url).attr("target", "ssoLinkOpen").submit();
#
#        	}
#     }
#
#     function checkUrlForm(linkUrlAdres) {
#        	var expUrl = /^http[s]?\:\/\//i;
#        	if (!expUrl.test(linkUrlAdres)) {
#        		linkUrlAdres = "http://"+linkUrlAdres;
#        	}
#        	return linkUrlAdres;
#     }
#
#     $(function() {
#
#         var swiper = new Swiper('.tutorial-slide', {
#             slidesPerView: 1,
#             spaceBetween: 0,
#             loop: true,
#             navigation: {
#                 nextEl: '.swiper-button-next',
#                 prevEl: '.swiper-button-prev'
#             },
#             pagination: {
#                 el: '#tutorial-slide-pagination',
#                 clickable: true,
#                 type: 'bullets',
#                 renderBullet: function(index, className){
#
#                 	var slideTitle = '';
#
#                 	if(index == 0){
#                 		slideTitle = "비콘출결: 훈련장소 도착 시 알림 메시지 확인으로 간편하게 훈련출결을 지원하는 서비스 입니다. 위치 사용 동의가 필요합니다. 블루투스 기능이 켜져 있어야 합니다.";
#                 	}else if(index == 1){
#                 		slideTitle = "동영상시청: 국민내일배움카드를 발급 받기 위해서는 사전에 '훈련안내 동영상 시청'이 필요합니다.";
#                 	}else if(index == 2){
#                 		slideTitle = "QR출결: 훈련 출결을 QR인식으로 지원하는 서비스입니다. 위치 및 카메라 사용 동의가 필요합니다. 위치 기능이 켜져 있어야 합니다. 훈련지역에서만 출결 처리가 가능합니다.";
#                 	}else if(index == 3){
#                 		slideTitle = "QR출결: 1.출결화면에 입실버튼을 선택합니다., 2.스마트폰 카메라가 자동으로 실행됩니다., 3.스마트폰 카메라로 훈련과정 QR을 스캔합니다.";
#                 	}else if(index == 4){
#                 		slideTitle = "훈련과정검색: 과정명, 기관명, 유형, NCS직종, 지역, 개강일자 등 설정 검색을 하실 수 있습니다.";
#                 	}else if(index == 5){
#                 		slideTitle = "훈련과정상세: 훈련정보와 기관정보가 나에게 맞는지 확인하고, 상담 또는 수강신청이 가능합니다.";
#                 	}
#
#                 	return '<a href="#" class="' +className + '"  title="' +slideTitle + '"></a>'
#                 }
#             },
#             autoplay: false
#         })
#
#         //공유하기 레이어팝업 열기
#         $('.btn-share-in').click(function () {
#             $('.common-popup.share-in').fadeIn();
#         });
#         //레이어팝업 닫기
#         $('.common-popup .btn-close').click(function () {
#             $('.common-popup').hide();
#         });
#
#         //공유하기 URL
#         var URLcopy = $('.input-url').val();
#         $('.url-copy').click(function (event) {
#             event.preventDefault();
#             $('.url-copy-info').fadeToggle();
#         });
#
#     	var copyUrl = document.getElementById("copy_url");
#     	copyUrl.value = window.document.location.href; // 현재 URL 셋팅
#
#         $('#copy_url_btn').click(function(){
#         	copyUrl.select(); // 해당 값 선택
#             document.execCommand("copy"); // 클립보드 복사
#             alert("URL이 복사되었습니다." + URLcopy);
#         });
#
#
#         /*
#         //현재창 URL삽입
#         $('.input-url').attr('value', window.location.href);
#         //URL 복사
#         var URLinput = $('.input-url');
#         $('.btn-copy').click(function () {
#             URLinput.focus();
#             URLinput.select();
#             URLinput.setSelectionRange(0, 999999);
#             document.execCommand("copy");
#             alert("URL이 복사되었습니다." + URLcopy);
#         })
#         */
#
#         function copyClipboardUrl(){
#         	var copyUrl = document.getElementById("copy_url");
#         	copyUrl.value = window.document.location.href; // 현재 URL 셋팅
#         	copyUrl.select(); // 해당 값 선택
#             document.execCommand("copy"); // 클립보드 복사
#             alert("URL이 복사되었습니다." + URLcopy);
#         }
#
#
#         $('.floatingMenu li.help a').on("click", function (event) {
#         	event.preventDefault();
#         	wpopLayer('/jsp/openMobileTutorial.jsp',640,1000,'PC','', '도움말 보기');
#         });
#
#         if ('PC' != 'PC') {
#         	$(".totalMenuWrap").hide();
#         }
#
#         $("#petco0100").click(function() {
#             location.href = '/hrdp/et/petco/PETCO0100D.do';
#         });
#     	$("#petco0101").click(function() {
#     		location.href = '/hrdp/et/petco/PETCO0101D.do';
#     	});
#         $("#petbo0100").click(function() {
#             location.href='/hrdp/et/petbo/PETBO0100D.do';
#         });
#         $("#info").click(function() {
#             window.open("http://www.keis.or.kr/main/subIndex/1667.do", "_blank");
#         });
#         $("#location").click(function() {
#             window.open("http://www.keis.or.kr/main/subIndex/811.do", "_blank");
#         });
#         $("#footPolicy").click(function() {
#             location.href = '/hrdp/mb/pmbfo/PMBFO0101P.do';
#         });
#
#
#         if ('PC' == 'iPhone') {
#         	$('#floatingWrap').css("height", "110px");
# 			$('.floatingMenu').css("height", "110px");
#         }
#
#         document.addEventListener("deviceready", onDeviceReady, false);
#     	function onDeviceReady() {
#     		if(typeof(device) != 'undefined' && typeof(device.platform) != 'undefined' ) {
#     			if(device.platform == 'iOS') {
#     				if (device.appVersionCode < '21031') {
#     					$('#floatingWrap').css("bottom", ".5em");
#     				}
#     				$('#floatingWrap').css("height", "110px");
#     				$('.floatingMenu').css("height", "110px");
#     			}
#     		}
#     	}
#     });
#
# 	$(document).ready(function() {
# 		var devicePC = "PC";
# 		if(gfn_isNull(devicePC)) devicePC = "PC";
# 		if(devicePC == "PC") $($(".footerPolicy").children("ul")).css("width", "920px");
# 		$("#footerLink > ul").find("li").find("a").on("focus",function() {
# 			var slideIndex = $(this).parent().attr("data-swiper-slide-index");
# 			$("#disitalTechPagination").parent().find(".movieControlArea").find(".btnGroup").find(".swiper-button-play .pause").trigger('click');
# 			$($("#disitalTechPagination").find("span")[slideIndex]).trigger('click');
# 		});
#
# 		var docTit = document.title;
# 		var locHref = $("#locHref");
# 		var locHrefList = $("#locHref").find("li");
# 		var titleName = "";
# 		if(docTit){
# 			if(locHrefList+"" != "undefined" && locHrefList != null && locHrefList != ""){
# 				var findAHref = $(locHrefList[locHrefList.length-1]).find("a");
# 				if(findAHref+"" != "undefined" && findAHref != null && findAHref != ""){
# 					if($(findAHref).html()+"" != "undefined" && $(findAHref).html() != null && $(findAHref).html() != ""){
# 						titleName = $(findAHref).html();
# 						if(titleName != null){
# 							if(titleName.length > 2){
# 								document.title = $(findAHref).html() +" | HRD-Net";
# 							}
# 						}
# 					}
# 				}
# 			}
# 		}
#
# 	});
#
#
# </script>
# </div>
# <div id="myCourseDiv"></div>
# <div id="onlineGuideDiv"></div>
# <script type="text/javascript">
# /* 웹접근성 개선 180511 수정 */
# function goMyCourse() {
# // 	$("#myCourseDiv").load("/hrdp/hg/phgho/PHGHO0100P.do", function() {
# 	$("#myCourseDiv").load("/hrdp/ma/pmmao/fixesSearchPop.do", function() {
# 		$(".layer_container").attr("tabindex", "0");
# 		$(".layer_popup").find(".nofocus").remove();
# 		$(".layer_popup").prepend('<span class="nofocus" tabindex="0"></span>');
#
# 		$(".layer_container").focus();
#
# 		$(".nofocus").focus(function(e){
# 			e.preventDefault();
# 			$(".layer_btn_close").focus();
# 		})
#
# 		$(document).on("click", ".layer_btn_close", function(e) {
# 			$(document).find(".js-layer-open").focus();
# 			$(document).find(".js-layer-open").removeClass("js-layer-open");
# 			e.preventDefault();
# 		});
#
# 		$(".layer_btn_close").on("keydown", function(e){
# 			var keycode = (e.keyCode ? e.keyCode : e.which);
# 			var $firstElem = $(".layer_popup").find("a, input, select, button, [tabindex='0']:not(.nofocus)").filter(":first");
#
# 			if(keycode == 9){
# 				e.preventDefault();
# 				$firstElem.focus();
# 			}
# 		})
# 	});
# }
# /* 웹접근성 개선 180511 수정 */
#
# function goOnlineGuide() {
# 	$("#onlineGuideDiv").load("/hrdp/ma/pmmao/onlineGuidePop.do", function() {
# 		$(".layer_container").attr("tabindex", "0");
# 		$(".layer_popup").find(".nofocus").remove();
# 		$(".layer_popup").prepend('<span class="nofocus" tabindex="0"></span>');
#
# 		$(".layer_container").focus();
#
# 		$(".nofocus").focus(function(e){
# 			e.preventDefault();
# 			$(".layer_btn_close").focus();
# 		})
#
# 		$(document).on("click", ".layer_btn_close", function(e) {
# 			$(document).find(".js-layer-open").focus();
# 			$(document).find(".js-layer-open").removeClass("js-layer-open");
# 			e.preventDefault();
# 		});
#
# 		$(".layer_btn_close").on("keydown", function(e){
# 			var keycode = (e.keyCode ? e.keyCode : e.which);
# 			var $firstElem = $(".layer_popup").find("a, input, select, button, [tabindex='0']:not(.nofocus)").filter(":first");
#
# 			if(keycode == 9){
# 				e.preventDefault();
# 				$firstElem.focus();
# 			}
# 		})
# 	});
# }
#
#
# $(document).ready(function () {
# 	if($('.lnbArea').length > 0) {
# 		if($('#content').length > 0) {
# 			$(this).attr('href', '#content');
# 		} else if($('.contentArea').length > 0) {
# 			$('.contentArea').attr('id', 'contentArea');
# 			$(this).attr('href', '#contentArea');
# 		} else if($('.subContArea').length > 0) {
# 			$('.subContArea').attr('id', 'subContArea');
# 			$(this).attr('href', '#subContArea');
# 		}
# 	}
# 	// 메뉴미존재
# 	else {
# 		$(this).attr('href', '#subContentWrap');
# 	}
# });
#
# function callContentWrapDo(){
# 	$($("#contentWrap").find(".lnbArea")).attr("tabindex", "0");
#     //location.href="#subContentWrap";
#     console.log($($("#contentWrap").find(".subContArea")));
#     if($($("#contentWrap").find(".subContArea"))+"" != "undefined"){
#     	if($($("#contentWrap").find(".subContArea")).attr("id")+"" != "undefined" && $($("#contentWrap").find(".subContArea")).attr("id") != "" && $($("#contentWrap").find(".subContArea")).attr("id") != null){
#     		location.href="#"+$($("#contentWrap").find(".subContArea")).attr("id");
# 	    	$("#"+$($("#contentWrap").find(".subContArea")).attr("id")).focus();
#     	}else{
# 	    	$($("#contentWrap").find(".subContArea")).attr("id", "subContArea");
# 	    	location.href="#subContArea";
# 	    	$("#subContArea").focus();
#     	}
#     }
# }
#
# </script>
# </body>
# </html>

# %% [markdown]
# > 기관명

# %%
# 기관명
for organ in soup.select('p.add'):
    print(organ.text.strip())
    data.append(organ.text.strip())
# Out:
# 스마트인재개발원

# %% [markdown]
# > 과정명

# %%
# 과정명
for course in soup.select('h4.tit'):
    print(course.text.replace('\n','').replace('\t',''))
    data.append(course.text.replace('\n','').replace('\t',''))
# Out:
# 빅데이터 분석서비스 개발자과정(NCS)모집마감

# %%
for statues in soup.select('span.statusTag.gray'):
    print(statues.text.strip())
# Out:
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감
# 모집마감

# %% [markdown]
# > 훈련비

# %%
# 훈련비
for price in soup.select('p.price'):
    print(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))
    data.append(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))
# Out:
# 13,762,240 원

# %%
for i in soup.select('span.con'):
    if i.text.find('일') != -1:
        date = i.text.replace('\n,','').replace('\t','').strip().replace('\n','')
        print(f'date : {date}')
    elif i.text.find('세') != -1:
        age = i.text.replace('\n,','').replace('\t','').strip()
        print('age : ' + age)
    elif i.text.find(')') != -1:
        if  i.text.find('~') == -1:
            NCS = i.text.replace('\n,','').replace('\t','').strip()
            print('NCS : ' + NCS[:NCS.find('(')])
        else:
            print('datetime : ' + i.text.replace('\n,','').replace('\t','').strip())
    
#         data.append(i.text.replace('\n,','').replace('\t','').strip())
#     print(i.text.replace('\n', '').replace('\t','').strip())
# Out:
# NCS : 응용SW엔지니어링
# datetime : 2020-11-02
# ~2021-04-12
# (1회차)
# date : 116일,총928시간
# age : 27 세

# %%
# NCS 자격분류
for NCS in soup.select('span.con'):
    if re.findall('\d{6,}',NCS.text) != []:
        print(re.findall('.+\d{6,}.',NCS.text).pop().replace('\t',''))
# Out:
# 응용SW엔지니어링(20010202)

# %% [markdown]
# > span 태그가 적절하지 않음 -> 쓸데없는게 너무 뽑힘
#
# > 근데 대안도 없다 이걸로 가자

# %%
# 수강생 평균 연령대(세)

# %%
# 수강생 평균 만족도
soup.select('div.starRating')[0].get('aria-label')
# Out:
# '만족도 100점 기준86.88점'

# %%
# 훈련시간
for i in soup.select('span.con'):
    if i.text.find('일') != -1:
        print(i.text.replace('\n,','').replace('\t','').strip())
        data.append(i.text.replace('\n,','').replace('\t','').strip())
# Out:
# 116일,
# 총928시간

# %% [markdown]
# > table.view 태그로 회차별 정보 한 번에 뽑기

# %%
# 전체 회차
len(soup.select('a.tool_tip_btn'))
# Out:
# 14

# %%
# 회차별 만족도 
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            tableview = j.text.replace('\n','').replace('\t','').strip()
            if re.findall('[.\d]+\s점',tableview) != []:
                count -= 1
                print(f"{count}회차 : " + re.findall('[.\d]+\s점',tableview).pop().replace(' 점',''))
# Out:
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : 75.2
# 9회차 : 82.4
# 8회차 : 90.84
# 7회차 : 90
# 6회차 : 91.58
# 5회차 : 84.54
# 4회차 : 89.6
# 3회차 : 89.56
# 2회차 : 80.74
# 1회차 : 95.56

# %%
# 회차별 모집인원
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            if re.findall('\d+명/',j.text) != []:
                count -= 1
                print(f"{count}회차 : " + re.findall('\d+명/',j.text).pop().replace('/',''))
# Out:
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : 25명
# 9회차 : 25명
# 8회차 : 25명
# 7회차 : 25명
# 6회차 : 24명
# 5회차 : 25명
# 4회차 : 25명
# 3회차 : 25명
# 2회차 : 28명
# 1회차 : 28명

# %%
# ?????????????????????
# [(\d]+/ : 취업인원
# /\d+ : 수료인원
count = len(soup.select('a.tool_tip_btn')) + 1
break_count = 2 
comple = ''
entire = ''
for i in soup.select('table.view'):
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            break_count += 1
            if break_count % 3 == 0:
                if re.findall('\(/\)',j.text) != []:
                    count -= 1
                    print(f'{count}회차 : '+ re.findall('\(/\)',j.text).pop().strip('(').strip(')'))
#                     print('-')
#                     print('-')
                elif re.findall('[(\d]+/', j.text) != [] and re.findall('\d+\)', j.text) != []:
                    count -= 1
                    print(f'{count}회차 : '+ re.findall('[(\d]+/', j.text).pop().replace('(','') + re.findall('\d+\)', j.text).pop().replace(')',''))
#                     print(re.findall('[(\d]+/', j.text).pop().replace('(','')[:re.findall('[(\d]+/', j.text).pop().replace('(','').find('/')])
#                     print(re.findall('\d+\)', j.text).pop().replace(')','')[re.findall('\d+\)', j.text).pop().replace(')','').find('/')+1:])
#                     if re.findall('[(\d]+/', j.text) != []: # 훈련시작일 
#                         count -= 1
#                         comple = (re.findall('[(\d]+/', j.text).pop()) 
#                     if re.findall('\d+\)', j.text) != []:
#                         count -= 1
#                         entire = (re.findall('\d+\)', j.text).pop())
#                     print(f'{count}회차 : ',comple, entire)
            else:
                pass
# Out:
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : /
# 9회차 : /
# 8회차 : /23
# 7회차 : 20/23
# 6회차 : 1/19
# 5회차 : 15/18
# 4회차 : 14/25
# 3회차 : 2/23
# 2회차 : 16/21
# 1회차 : 21/26

# %%
# 취업률 (고용보험가입 3개월) 취업인원/수료인원
empl_rate_3 = [] # 회차별 취업률(3개월)
empl_3 = [] # 회차별 취업인원 (3개월)
comp_3 = [] # 회차별 수료인원 (3개월)
series_count = len(soup.select('a.tool_tip_btn'))
# count = len(soup.select('a.tool_tip_btn')) + 1
cnt = 0
for i in soup.select('table.view'):
    if i.text.find('취업률 고용보험가입 3개월') != -1:
        for j in i.select('b'):
            cnt += 1
            if cnt % 3 == 1:
                rate_empl = j.text.replace('\n','').replace('\t','')
                empl_rate_3.append(rate_empl[:rate_empl.find("%")])
                empl_3.append(rate_empl[rate_empl.find("%")+2:rate_empl.find("/")])
                comp_3.append(rate_empl[rate_empl.find("/")+1:-1])
#                 print(f'취업률 : {rate_empl[:rate_empl.find("%")]}')
#                 print(f'취업인원 : {rate_empl[rate_empl.find("%")+2:rate_empl.find("/")]}')
#                 print(f'수료인원 : {rate_empl[rate_empl.find("/")+1:-1]}')

while len(empl_rate_3) != series_count:
    empl_rate_3.insert(0,'훈련진행중')
while len(empl_3) != series_count:
    empl_3.insert(0,'훈련진행중')
while len(comp_3) != series_count:
    comp_3.insert(0,'훈련진행중')
print(empl_rate_3)
print(empl_3)
print(comp_3)
len(empl_rate_3), len(empl_3), len(comp_3)
# Out:
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '60.9', '87', '63.2', '0', '56', '73.9', '57.1', '80.8']
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '14', '20', '12', '0', '14', '17', '12', '21']
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '23', '23', '19', '18', '25', '23', '21', '26']
# (14, 14, 14)

# %%
# 취업률 (고용보험가입 6개월) 취업인원/수료인원


count = len(soup.select('a.tool_tip_btn')) + 1
cnt = 0
for i in soup.select('table.view'):
    if i.text.find('취업률 고용보험가입 6개월') != -1:
        for j in i.select('b'):
            cnt += 1
            if cnt % 3 == 2:
                rate_empl = j.text.replace('\n','').replace('\t','')
                print(f'취업률 : {rate_empl[:rate_empl.find("%")]}')
                print(f'취업인원 : {rate_empl[rate_empl.find("%")+2:rate_empl.find("/")]}')
                print(f'수료인원 : {rate_empl[rate_empl.find("/")+1:-1]}')
# Out:
# 취업률 :
# 취업인원 :
# 수료인원 :
# 취업률 :
# 취업인원 :
# 수료인원 :
# 취업률 :
# 취업인원 :
# 수료인원 : 23
# 취업률 :
# 취업인원 :
# 수료인원 : 23
# 취업률 : 84.2
# 취업인원 : 16
# 수료인원 : 19
# 취업률 : 83.3
# 취업인원 : 15
# 수료인원 : 18
# 취업률 : 72
# 취업인원 : 18
# 수료인원 : 25
# 취업률 : 82.6
# 취업인원 : 19
# 수료인원 : 23
# 취업률 : 76.2
# 취업인원 : 16
# 수료인원 : 21
# 취업률 : 92.3
# 취업인원 : 24
# 수료인원 : 26

# %%
count = len(soup.select('a.tool_tip_btn')) + 1
for series in soup.select('span.con')[17:]:
    if series.text.find('~') != -1:
        count -= 1
        print(f'{count}회차 : ')
        print(series.text.replace('\n','').replace('\t','').strip()[:series.text.replace('\n','').replace('\t','').strip().find('~')])
        print(series.text.replace('\n','').replace('\t','').strip()[series.text.replace('\n','').replace('\t','').strip().find('~')+1:])
# Out:
# 14회차 :
# 2022-05-02
# 2022-10-18
# 13회차 :
# 2022-03-14
# 2022-08-24
# 12회차 :
# 2022-02-15
# 2022-08-04
# 11회차 :
# 2022-02-15
# 2022-08-04
# 10회차 :
# 2022-01-10
# 2022-06-23
# 9회차 :
# 2021-12-01
# 2022-05-17
# 8회차 :
# 2021-11-15
# 2022-04-27
# 7회차 :
# 2021-09-15
# 2022-02-28
# 6회차 :
# 2021-08-25
# 2022-01-28
# 5회차 :
# 2021-04-01
# 2021-08-31
# 4회차 :
# 2021-03-17
# 2021-08-19
# 3회차 :
# 2021-03-15
# 2021-08-13
# 2회차 :
# 2020-12-07
# 2021-05-21
# 1회차 :
# 2020-11-02
# 2021-04-12

# %%
# 수강확정인원, 수강신청인원
for a in soup.select('table.view'):
    for b in a.select('td'):
        if b.text.find('수강확정인원') != -1:
            print(re.findall('\d+',b.text))
# Out:
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['24', '24']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['28', '28']
# ['28', '28']

# %% [markdown]
# ### 회차목록에서 얻은 것들
# ---
# > 회차별 만족도
#
# > 회차별 모집인원
#
# > 회차별 취업인원/수료인원
#
# > 훈련시작일 ~훈련종료일
#
# > 수강확정인원, 수강신청인원

# %% [markdown]
# ### 일단 회차목록에서 얻을 수 있는 것들 다 얻음.
# ---
# > N회차 보러가기 링크 들어가서 안에서 찾을 수 있는 것을 찾기
#
# - 기관명
# - 과정명
# - 훈련비
# - 훈련기간

# %% [markdown]
# > N회차 보러가기 링크 따기

# %% [markdown]
# 1. 기관명 ok
# 2. 과정명 ok
# 3. 훈련비(원) ok
# 4. 훈련시간 ok
# 5. NCS 직무분류 ok
# 6. 수강생 평균 연령대(세) ok
# 7. 수강생 평균 만족도 ok
# 8. 회차 ok
# 9. 훈련기간 ok
# 10. 훈련시작일 ok
# 11. 훈련종료일 ok
# 12. 모집인원 ok
# 13. 수강확정인원 ok
# 14. 수강신청인원 ok
# 15. 회차별 만족도 ok
# 16. 취업률 고용보험가입 3개월 ok
# 17. 취업인원 ok
# 18. 수료인원 ok

# %%
# 회차별 만족도
print('-'*15,'회차별 만족도','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            tableview = j.text.replace('\n','').replace('\t','').strip()
            if re.findall('[.\d]+\s점',tableview) != []:
                count -= 1
                print(f"{count}회차 : " + re.findall('[.\d]+\s점',tableview).pop().replace(' 점',''))

# 회차별 훈련기간
print('-'*15,'회차별 훈련기간','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for series in soup.select('span.con')[17:]:
    if series.text.find('~') != -1:
        count -= 1
        print(f'{count}회차 : ' + series.text.replace('\n','').replace('\t','').strip())
        
# 회차별 모집인원
print('-'*15,'회차별 모집인원','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            if re.findall('\d+명/',j.text) != []:
                count -= 1
                print(f"{count}회차 : " + re.findall('\d+명/',j.text).pop().replace('/',''))


# 회차별 수료, 취업 인원
print('-'*15,'회차별 [수료, 취업]인원','-'*15)
# [(\d]+/ : 취업인원
# /\d+ : 수료인원
count = len(soup.select('a.tool_tip_btn')) + 1
break_count = 2 
comple = ''
entire = ''
for i in soup.select('table.view'):
    if i.text.find('훈련진행중') != -1:
        count -= 1
        print(f'{count}회차 : 훈련진행중')
    else:
        for j in i.select('td'):
            break_count += 1
            if break_count % 3 == 0:
                if re.findall('\(/\)',j.text) != []:
                    count -= 1
                    print(f'{count}회차 : ' +re.findall('\(/\)',j.text).pop())
                elif re.findall('[(\d]+/', j.text) != [] and re.findall('\d+\)', j.text) != []:
                    count -= 1
                    print(f'{count}회차 : '+(re.findall('[(\d]+/', j.text).pop().replace('(','')) + re.findall('\d+\)', j.text).pop().replace(')',''))
            else:
                pass
            
# 회차별 수강확정인원, 수강신청인원
print('-'*15,'회차별 수강 [확정,신청] 인원','-'*15)
for a in soup.select('table.view'):
    for b in a.select('td'):
        if b.text.find('수강확정인원') != -1:
            print(re.findall('\d+',b.text))
for index, patterns in enumerate(soup.select('a.tool_tip_btn')):
    series_url = f'https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&tracseTme={index+1}&crseTracseSe=C0061&trainstCstmrId=500020018488#undefined'
    resp_series = requests.get(series_url)
    soup_series = BeautifulSoup(resp_series.text, "html.parser")
    
    print(f'----------------{index+1} 회차 ---------------')
    
    # 차단 방지 시간 딜레이
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    
    # 기관명
    for organ in soup_series.select('p.add'):
        print(organ.text.strip())
#     data.append(organ.text.strip())
    
    # 과정명
    for course in soup_series.select('h4.tit'):
        print(course.text.replace('\n','').replace('\t',''))
#     data.append(course.text.replace('\n','').replace('\t',''))
    
    # 훈련비
    for price in soup_series.select('p.price'):
        print(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))
#     data.append(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))

    # 훈련시간
    for i in soup_series.select('span.con'):
        if i.text.find('일') != -1:
            print(i.text.replace('\n,','').replace('\t','').strip())
#             data.append(i.text.replace('\n,','').replace('\t','').strip())
    # NCS 자격분류
    for NCS in soup_series.select('span.con'):
        if re.findall('\d{6,}',NCS.text) != []:
            print(re.findall('.+\d{6,}.',NCS.text).pop().replace('\t',''))
# Out:
# --------------- 회차별 만족도 ---------------
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : 75.2
# 9회차 : 82.4
# 8회차 : 90.84
# 7회차 : 90
# 6회차 : 91.58
# 5회차 : 84.54
# 4회차 : 89.6
# 3회차 : 89.56
# 2회차 : 80.74
# 1회차 : 95.56
# --------------- 회차별 훈련기간 ---------------
# 14회차 : 2022-05-02 ~2022-10-18
# 13회차 : 2022-03-14 ~2022-08-24
# 12회차 : 2022-02-15 ~2022-08-04
# 11회차 : 2022-02-15 ~2022-08-04
# 10회차 : 2022-01-10 ~2022-06-23
# 9회차 : 2021-12-01 ~2022-05-17
# 8회차 : 2021-11-15 ~2022-04-27
# 7회차 : 2021-09-15 ~2022-02-28
# 6회차 : 2021-08-25 ~2022-01-28
# 5회차 : 2021-04-01 ~2021-08-31
# 4회차 : 2021-03-17 ~2021-08-19
# 3회차 : 2021-03-15 ~2021-08-13
# 2회차 : 2020-12-07 ~2021-05-21
# 1회차 : 2020-11-02 ~2021-04-12
# --------------- 회차별 모집인원 ---------------
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : 25명
# 9회차 : 25명
# 8회차 : 25명
# 7회차 : 25명
# 6회차 : 24명
# 5회차 : 25명
# 4회차 : 25명
# 3회차 : 25명
# 2회차 : 28명
# 1회차 : 28명
# --------------- 회차별 [수료, 취업]인원 ---------------
# 14회차 : 훈련진행중
# 13회차 : 훈련진행중
# 12회차 : 훈련진행중
# 11회차 : 훈련진행중
# 10회차 : (/)
# 9회차 : (/)
# 8회차 : /23
# 7회차 : 20/23
# 6회차 : 1/19
# 5회차 : 15/18
# 4회차 : 14/25
# 3회차 : 2/23
# 2회차 : 16/21
# 1회차 : 21/26
# --------------- 회차별 수강 [확정,신청] 인원 ---------------
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['24', '24']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['28', '28']
# ['28', '28']
# ----------------1 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------2 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------3 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------4 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------5 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------6 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 115일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------7 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 116일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------8 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------9 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------10 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 118일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------11 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 118일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------12 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 118일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------13 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 118일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------14 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)

# %% [markdown]
# # DateFrame

# %% [markdown]
# ## Difine column

# %% [markdown]
# > 기존에서 순서 바꾸고, 중복 제거

# %%
col, len(col)
# Out:
# (['기관명',
#   '과정명',
#   '훈련비(원)',
#   '훈련시간',
#   'NCS 직무분류',
#   '수강생 평균 연령대(세)',
#   '수강생 평균 만족도',
#   '회차',
#   '훈련기간',
#   '훈련시작일',
#   '훈련종료일',
#   '모집인원',
#   '수강확정인원',
#   '수강신청인원',
#   '회차별 만족도',
#   '취업률 고용보험가입 3개월',
#   '취업인원',
#   '수료인원'],
#  18)

# %% [markdown]
# 순서이렇게 하자
#
# > 기관명, 과정명, 회차, 훈련비, 훈련시작일, 훈련종료일, 훈련시간, NCS 직무분류, 모집인원, 수강확정인원, 수강신청인원, 수강생 평균 연령대(세), 수강생 만족도, 취업률 고용보험가입 3개월, 취업인원(3개월), 수료인원, 취업률 고용보험가입 6개월, 취업인원(6개월)
#
# > column size : 18
#
# - 훈련시간, 회차별 만족도 -> 중복으로 뺌

# %%
col = ['기관명', '과정명', '회차', '훈련비', '훈련시작일', '훈련종료일', 
       '훈련시간', 'NCS 직무분류', '모집인원', '수강확정인원', '수강신청인원', 
       '수강생 평균 연령대(세)', '수강생 만족도', '취업률 고용보험가입 3개월', 
       '취업인원(3개월)', '수료인원','취업률 고용보험가입 6개월', '취업인원(6개월)']
len(col)
# Out:
# 18

# %% [markdown]
# ## 데이터 프레임 열만 생성

# %%
df = pd.DataFrame(columns = col)
df
# Out:
# Empty DataFrame
# Columns: [기관명, 과정명, 회차, 훈련비, 훈련시작일, 훈련종료일, 훈련시간, NCS 직무분류, 모집인원, 수강확정인원, 수강신청인원, 수강생 평균 연령대(세), 수강생 만족도, 취업률 고용보험가입 3개월, 취업인원(3개월), 수료인원, 취업률 고용보험가입 6개월, 취업인원(6개월)]
# Index: []

# %% [markdown]
# ## 데이터 추가
#
# > 1. concat : 추가할 대상이 데이터 프레임
#
# > 2. append : 추가할 대상이 딕셔너리 -> 컬럼 이름 : key, 데이터 : value
#
# > 3. loc : 추가할 대상이 리스트 -> 이때 loc에 들어가는 인덱스는 맨 마지막 인덱스로 설정.

# %% [markdown]
# 일단 뭐든 시도

# %% [markdown]
# 회차별로 한 번에 뽑을 수 있는 데이터는 따로 모을 예정

# %% [markdown]
# ### dictionary로 만들어서 DataFrame에 append 해야 겠다.
# ---

# %% [markdown]
# > 각 컬럼 종류별로 리스트로 넣고 join 함수로 str로 바꿔서 dictionary에 넣고 미리 만든 df랑 append로 합치기

# %% [markdown]
# #### 각 column별로 마지막 회차 ~ 1회차 까지 list로 저장

# %%
# 베이스 url
url = 'https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&tracseTme=1&crseTracseSe=C0061&trainstCstmrId=500020018488#undefined'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')

sati = [] # 회차별 만족도
prev = [] # 회차별 훈련시작
fini = [] # 회차별 훈련종료
recu = [] # 회차별 모집인원
conf = [] # 회차별 수강확정인원
appl = [] # 회차별 수강신청인원
empl_rate_3 = [] # 회차별 취업률(3개월)
empl_3 = [] # 회차별 취업인원 (3개월)
comp_3 = [] # 회차별 수료인원 (3개월)
empl_rate_6 = [] # 회차별 취업률(6개월)
empl_6 = [] # 회차별 취업인원 (6개월)
comp_6 = [] # 회차별 수료인원 (6개월)


# 회차별 만족도
print('-'*15,'회차별 만족도','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        sati.append('훈련진행중')
        print(f'{count}회차 만족도 수집 완료')
    else:
        for j in i.select('td'):
            tableview = j.text.replace('\n','').replace('\t','').strip()
            if re.findall('[.\d]+\s점',tableview) != []:
                count -= 1
                sati.append(re.findall('[.\d]+\s점',tableview).pop().replace(' 점',''))
                print(f"{count}회차 만족도 수집 완료")
print('회차별 만족도 결과')
print(sati)
print(f'size : {len(sati)}')

# 회차별 훈련기간
print('-'*15,'회차별 훈련기간','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for series in soup.select('span.con')[17:]:
    if series.text.find('~') != -1:
        count -= 1
        print(f'{count}회차 훈련 시작일, 종료일 수집 완료')
        prev.append(series.text.replace('\n','').replace('\t','').strip()[:series.text.replace('\n','').replace('\t','').strip().find('~')])
        fini.append(series.text.replace('\n','').replace('\t','').strip()[series.text.replace('\n','').replace('\t','').strip().find('~')+1:])
#         print(series.text.replace('\n','').replace('\t','').strip()[:series.text.replace('\n','').replace('\t','').strip().find('~')])
#         print(series.text.replace('\n','').replace('\t','').strip()[series.text.replace('\n','').replace('\t','').strip().find('~')+1:])
print('회차별 시작일')
print(prev)
print(f'size : {len(prev)}')
print('회차별 종료일')
print(fini)
print(f'size : {len(fini)}')

# 회차별 모집인원
print('-'*15,'회차별 모집인원','-'*15)
count = len(soup.select('a.tool_tip_btn')) + 1
for i in soup.select('table.view')[2:]:
    if i.text.find('훈련진행중') != -1:
        count -= 1
        recu.append('훈련진행중')
        print(f'{count}회차 모집인원 수집 완료')
    else:
        for j in i.select('td'):
            if re.findall('\d+명/',j.text) != []:
                count -= 1
                recu.append(re.findall('\d+명/',j.text).pop().replace('명/',''))
                print(f"{count}회차 : 모집인원 수집 완료")
print('회차별 모집인원')
print(recu)
print(f'size : {len(recu)}')
                      
# 취업률 (고용보험가입 3개월) 취업인원/수료인원
series_count = len(soup.select('a.tool_tip_btn'))
# count = len(soup.select('a.tool_tip_btn')) + 1
cnt = 0
for i in soup.select('table.view'):
    if i.text.find('취업률 고용보험가입 3개월') != -1:
        for j in i.select('b'):
            cnt += 1
            if cnt % 3 == 1:
                rate_empl = j.text.replace('\n','').replace('\t','')
                empl_rate_3.append(rate_empl[:rate_empl.find("%")])
                empl_3.append(rate_empl[rate_empl.find("%")+2:rate_empl.find("/")])
                comp_3.append(rate_empl[rate_empl.find("/")+1:-1])
                print('취업률 수집 완료')
while len(empl_rate_3) != series_count:
    empl_rate_3.insert(0,'훈련진행중')
while len(empl_3) != series_count:
    empl_3.insert(0,'훈련진행중')
while len(comp_3) != series_count:
    comp_3.insert(0,'훈련진행중')
print(empl_rate_3)
print(f'size : {len(empl_rate_3)}')
print(empl_3)
print(f'size : {len(empl_3)}')
print(comp_3)
print(f'size : {len(comp_3)}')
# 회차별 수강확정인원, 수강신청인원
print('-'*15,'회차별 수강 [확정,신청] 인원','-'*15)
for a in soup.select('table.view'):
    for b in a.select('td'):
        if b.text.find('수강확정인원') != -1:
            print(re.findall('\d+',b.text))
            conf.append(re.findall('\d+',b.text)[0])
            appl.append(re.findall('\d+',b.text)[1])
print('수강확정인원')
print(conf)
print(f'size : {len(conf)}')
print('수강신청인원')
print(appl)
print(f'size : {len(appl)}')

count = len(soup.select('a.tool_tip_btn')) + 1
    
for patterns in soup.select('a.tool_tip_btn'):
    series_url = f'https://www.hrd.go.kr/hrdp/co/pcobo/PCOBO0100P.do?tracseId=AIG20200000286660&tracseTme={index+1}&crseTracseSe=C0061&trainstCstmrId=500020018488#undefined'
    resp_series = requests.get(series_url)
    soup_series = BeautifulSoup(resp_series.text, "html.parser")

    count -= 1
    print(f'----------------{count} 회차 ---------------')
    
    # 차단 방지 시간 딜레이
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    
    # 기관명
    for organ in soup_series.select('p.add'):
        print(organ.text.strip())
#     data.append(organ.text.strip())
    
    # 과정명
    for course in soup_series.select('h4.tit'):
        print(course.text.replace('\n','').replace('\t',''))
#     data.append(course.text.replace('\n','').replace('\t',''))
    
    # 훈련비
    for price in soup_series.select('p.price'):
        print(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))
#     data.append(price.text.strip().replace('\n','')[:price.text.find('원')].strip().replace('\t',''))

    # 훈련시간
    for i in soup_series.select('span.con'):
        if i.text.find('일') != -1:
            print(i.text.replace('\n,','').replace('\t','').strip())
#             data.append(i.text.replace('\n,','').replace('\t','').strip())
    # NCS 자격분류
    for NCS in soup_series.select('span.con'):
        if re.findall('\d{6,}',NCS.text) != []:
            print(re.findall('.+\d{6,}.',NCS.text).pop().replace('\t',''))
# Out:
# --------------- 회차별 만족도 ---------------
# 14회차 만족도 수집 완료
# 13회차 만족도 수집 완료
# 12회차 만족도 수집 완료
# 11회차 만족도 수집 완료
# 10회차 만족도 수집 완료
# 9회차 만족도 수집 완료
# 8회차 만족도 수집 완료
# 7회차 만족도 수집 완료
# 6회차 만족도 수집 완료
# 5회차 만족도 수집 완료
# 4회차 만족도 수집 완료
# 3회차 만족도 수집 완료
# 2회차 만족도 수집 완료
# 1회차 만족도 수집 완료
# 회차별 만족도 결과
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '75.2', '82.4', '90.84', '90', '91.58', '84.54', '89.6', '89.56', '80.74', '95.56']
# size : 14
# --------------- 회차별 훈련기간 ---------------
# 14회차 훈련 시작일, 종료일 수집 완료
# 13회차 훈련 시작일, 종료일 수집 완료
# 12회차 훈련 시작일, 종료일 수집 완료
# 11회차 훈련 시작일, 종료일 수집 완료
# 10회차 훈련 시작일, 종료일 수집 완료
# 9회차 훈련 시작일, 종료일 수집 완료
# 8회차 훈련 시작일, 종료일 수집 완료
# 7회차 훈련 시작일, 종료일 수집 완료
# 6회차 훈련 시작일, 종료일 수집 완료
# 5회차 훈련 시작일, 종료일 수집 완료
# 4회차 훈련 시작일, 종료일 수집 완료
# 3회차 훈련 시작일, 종료일 수집 완료
# 2회차 훈련 시작일, 종료일 수집 완료
# 1회차 훈련 시작일, 종료일 수집 완료
# 회차별 시작일
# ['2022-05-02 ', '2022-03-14 ', '2022-02-15 ', '2022-02-15 ', '2022-01-10 ', '2021-12-01 ', '2021-11-15 ', '2021-09-15 ', '2021-08-25 ', '2021-04-01 ', '2021-03-17 ', '2021-03-15 ', '2020-12-07 ', '2020-11-02 ']
# size : 14
# 회차별 종료일
# ['2022-10-18', '2022-08-24', '2022-08-04', '2022-08-04', '2022-06-23', '2022-05-17', '2022-04-27', '2022-02-28', '2022-01-28', '2021-08-31', '2021-08-19', '2021-08-13', '2021-05-21', '2021-04-12']
# size : 14
# --------------- 회차별 모집인원 ---------------
# 14회차 모집인원 수집 완료
# 13회차 모집인원 수집 완료
# 12회차 모집인원 수집 완료
# 11회차 모집인원 수집 완료
# 10회차 : 모집인원 수집 완료
# 9회차 : 모집인원 수집 완료
# 8회차 : 모집인원 수집 완료
# 7회차 : 모집인원 수집 완료
# 6회차 : 모집인원 수집 완료
# 5회차 : 모집인원 수집 완료
# 4회차 : 모집인원 수집 완료
# 3회차 : 모집인원 수집 완료
# 2회차 : 모집인원 수집 완료
# 1회차 : 모집인원 수집 완료
# 회차별 모집인원
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '25', '25', '25', '25', '24', '25', '25', '25', '28', '28']
# size : 14
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# 취업률 수집 완료
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '60.9', '87', '63.2', '0', '56', '73.9', '57.1', '80.8']
# size : 14
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '14', '20', '12', '0', '14', '17', '12', '21']
# size : 14
# ['훈련진행중', '훈련진행중', '훈련진행중', '훈련진행중', '', '', '23', '23', '19', '18', '25', '23', '21', '26']
# size : 14
# --------------- 회차별 수강 [확정,신청] 인원 ---------------
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['24', '24']
# ['25', '25']
# ['25', '25']
# ['25', '25']
# ['28', '28']
# ['28', '28']
# 수강확정인원
# ['25', '25', '25', '25', '25', '25', '25', '25', '24', '25', '25', '25', '28', '28']
# size : 14
# 수강신청인원
# ['25', '25', '25', '25', '25', '25', '25', '25', '24', '25', '25', '25', '28', '28']
# size : 14
# ----------------14 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------13 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------12 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------11 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------10 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------9 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------8 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------7 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------6 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------5 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------4 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------3 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------2 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)
# ----------------1 회차 ---------------
# 스마트인재개발원
# 빅데이터 분석서비스 개발자과정(NCS)모집마감
# 13,762,240 원
#
# 119일,
# 총928시간
# 응용SW엔지니어링(20010202)

# %% [markdown]
# #### list -> str -> dictionary 로 변환

# %% [markdown]
# #### dictionary -> DataFrame 변환
